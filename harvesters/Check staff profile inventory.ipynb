# %% [markdown]
# This process ended up initially being kind of a mess. I had a bunch of duplicates and other issues to hash through before finally being able to add a few hundred additional person items that were indicated by the Staff Profile inventory. I will come back and revisit this at a later time once I get a proper baseline established.

# %%
import os
import mwclient
import requests
import pandas as pd
import isaid
from joblib import Parallel, delayed
from tqdm import tqdm
import yaml

from wbmaker import WikibaseConnection
geokb = WikibaseConnection('GEOKB_CLOUD')

# %%
source_item = "Q44323"

# %%
# Create a secure connection to the Wikibase so we can write to it
def create_authenticated_site(user_name, password):
    site = mwclient.Site('geokb.wikibase.cloud', path='/w/', scheme='https')
    site.login(user_name, password)

    return site

def df_from_sparql(json_results):
    data_records = []
    var_names = json_results['head']['vars']

    for record in json_results['results']['bindings']:
        data_record = {}
        for var_name in var_names:
            data_record[var_name] = record[var_name]['value'] if var_name in record else None
        data_records.append(data_record)

    return pd.DataFrame(data_records)

# %%
# Establish GeoKB Wikibase site connection
mw_site = create_authenticated_site(os.environ['WB_BOT_GEOKB_CLOUD'], os.environ['WB_BOT_PASS_GEOKB_CLOUD'])  

source_page = mw_site.pages[f"Item_talk:{source_item}"]
profile_list = source_page.text().split(',')

# %%
query_person_profiles = """
PREFIX wd: <https://geokb.wikibase.cloud/entity/>
PREFIX wdt: <https://geokb.wikibase.cloud/prop/direct/>
PREFIX p: <https://geokb.wikibase.cloud/prop/>
PREFIX ps: <https://geokb.wikibase.cloud/prop/statement/>
PREFIX pq: <https://geokb.wikibase.cloud/prop/qualifier/>

SELECT ?item ?itemLabel ?profile_url ?retrieved ?status_code ?orcid ?email
WHERE {
  # ?item wdt:P1 wd:Q3 .
  OPTIONAL {
    # ?item wdt:P31 ?profile_url .
  }
  OPTIONAL {
    # ?item wdt:P106 ?orcid .
  }
  OPTIONAL {
    # ?item wdt:P109 ?email .
  }
  OPTIONAL {
    # ?item p:P31 ?ref_url_statement .
    # ?ref_url_statement pq:P151 ?status_code ;
                       pq:P139 ?retrieved .
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""

r = requests.get(
    'https://geokb.wikibase.cloud/query/sparql',
    params = {'query': query_person_profiles, 'format': 'json'}
)

df_geokb_profiles = df_from_sparql(r.json())
df_geokb_profiles['qid'] = df_geokb_profiles['item'].apply(lambda x: x.split('/')[-1])
df_geokb_profiles['profile_name'] = df_geokb_profiles['profile_url'].apply(lambda x: x.split('/')[-1] if x else None)
df_geokb_profiles['email'] = df_geokb_profiles['email'].apply(lambda x: x.split(':')[-1] if x else None)

orcid_lookup = df_geokb_profiles[df_geokb_profiles['orcid'].notnull()].set_index('orcid')['qid'].to_dict()

df_geokb_profiles.head()
# Out:
#                                          item         itemLabel  \
# 0  https://geokb.wikibase.cloud/entity/Q44897  John Karl Bohlke
# 1  https://geokb.wikibase.cloud/entity/Q44898      Carol Bolden
# 2  https://geokb.wikibase.cloud/entity/Q44900     Wallace Bolen
# 3  https://geokb.wikibase.cloud/entity/Q44902  Scott Bonar, PhD
# 4  https://geokb.wikibase.cloud/entity/Q44904     Michael Bonds
#
#                                          profile_url             retrieved  \
# 0  https://www.usgs.gov/staff-profiles/john-karl-...  2023-09-30T00:00:00Z
# 1   https://www.usgs.gov/staff-profiles/carol-bolden  2023-09-30T00:00:00Z
# 2  https://www.usgs.gov/staff-profiles/wallace-bolen  2023-09-30T00:00:00Z
# 3    https://www.usgs.gov/staff-profiles/scott-bonar  2023-09-30T00:00:00Z
# 4  https://www.usgs.gov/staff-profiles/michael-bonds  2023-09-30T00:00:00Z
#
#   status_code                orcid              email     qid  \
# 0         200  0000-0001-5693-6455  jkbohlke@usgs.gov  Q44897
# 1         200                 None   cbolden@usgs.gov  Q44898
# 2         200                 None    wbolen@usgs.gov  Q44900
# 3         200  0000-0003-3532-4067    sbonar@usgs.gov  Q44902
# 4         200  0000-0002-9454-1195    mbonds@usgs.gov  Q44904
#
#        profile_name
# 0  john-karl-bohlke
# 1      carol-bolden
# 2     wallace-bolen
# 3       scott-bonar
# 4     michael-bonds

# %%
missing_url = df_geokb_profiles[df_geokb_profiles['profile_url'].isna()].reset_index(drop=True)
print("PEOPLE IN GEOKB", len(df_geokb_profiles))
print("PEOPLE MISSING PROFILES", len(missing_url))
print()
missing_profile_names = [i for i in profile_list if i not in df_geokb_profiles['profile_name'].tolist()]
print("POTENTIALLY NEW PEOPLE", len(missing_profile_names))
display(missing_profile_names[:5])
# Out:
# PEOPLE IN GEOKB 10753
# PEOPLE MISSING PROFILES 4802
#
# POTENTIALLY NEW PEOPLE 404
# ['tim-clements',
#  'sabrina-n-martinez',
#  'seth-siefken',
#  'cayla-shirley',
#  'michael-utecht']

# %% [markdown]
# # Scrape Profiles

# %%
missing_profiles = Parallel(n_jobs=-1, prefer='threads')(delayed(isaid.staff_profile_scrape)(i) for i in tqdm(missing_profile_names))
# Out:
# 100%|██████████| 564/564 [01:13<00:00,  7.68it/s]

# %%
for profile_name in [i for i in missing_profile_names if i not in df_missing_profiles['profile_name'].tolist()]:
    missing_profiles.append(isaid.staff_profile_scrape(profile_name))

# %%
df_missing_profiles = pd.DataFrame([{**d['profile'], **d['meta']} for d in missing_profiles])
df_missing_profiles['profile_name'] = df_missing_profiles['url'].apply(lambda x: x.split('/')[-1])
df_missing_profiles = df_missing_profiles[
    (df_missing_profiles['profile_name'].isin(missing_profile_names))
    &
    (~df_missing_profiles['orcid'].isin(orcid_lookup))
    &
    (
        (df_missing_profiles['email'].notnull())
        |
        (df_missing_profiles['orcid'].notnull())
    )
].reset_index(drop=True)

df_missing_profiles.head()
# Out:
#                  name name_qualifier                            title  \
# 0        Tim Clements           None                        Scientist
# 1  Sabrina N Martinez           None                        Geologist
# 2        Seth Siefken           None  Hydrologist - Civil Engineering
# 3       Cayla Shirley           None            Hydrologic Technician
# 4      Michael Utecht           None                    IT Specialist
#
#                              organization_name  \
# 0                   Earthquake Hazards Program
# 1                    Landslide Hazards Program
# 2         Wyoming-Montana Water Science Center
# 3                  Oregon Water Science Center
# 4  Upper Midwest Environmental Sciences Center
#
#                                    organization_link                email  \
# 0   https://www.usgs.gov/programs/earthquake-hazards   tclements@usgs.gov
# 1    https://www.usgs.gov/programs/landslide-hazards  snmartinez@usgs.gov
# 2  https://www.usgs.gov/centers/wyoming-montana-w...    ssiefken@usgs.gov
# 3  https://www.usgs.gov/centers/oregon-water-scie...    cshirley@usgs.gov
# 4  https://www.usgs.gov/centers/upper-midwest-env...     mutecht@usgs.gov
#
#                  orcid                                   intro_statements  \
# 0                 None                                     [Tim Clements]
# 1  0000-0002-1812-5990  [Sabrina Martinez joined the team at the USGS ...
# 2  0000-0001-5502-7903  [Seth Siefken is a civil engineer based in Hel...
# 3                 None  [Cayla is a hydrologic technician at the Orego...
# 4                 None                                   [Michael Utecht]
#
#   expertise_terms                            professional_experience  \
# 0              []                                                 []
# 1    [Landslides]  [2020 - Present: Geologist, USGS Geologic Haza...
# 2              []                                                 []
# 3              []                                                 []
# 4              []                                                 []
#
#                                            education affiliations honors  \
# 0                                                 []           []     []
# 1  [2017-2019: Tulane University, M.S., Earth and...           []     []
# 2  [M.S. Civil Engineering, Colorado State Univer...           []     []
# 3                                                 []           []     []
# 4                                                 []           []     []
#
#   abstracts                                 personal_statement  \
# 0        []                                               None
# 1        []  Sabrina uses remotely sensed data to better un...
# 2        []                                               None
# 3        []                                               None
# 4        []                                               None
#
#                                                  url  \
# 0   https://www.usgs.gov/staff-profiles/tim-clements
# 1  https://www.usgs.gov/staff-profiles/sabrina-n-...
# 2   https://www.usgs.gov/staff-profiles/seth-siefken
# 3  https://www.usgs.gov/staff-profiles/cayla-shirley
# 4  https://www.usgs.gov/staff-profiles/michael-ut...
#
#                     timestamp  status_code        profile_name
# 0  2023-10-02T16:15:28.619274          200        tim-clements
# 1  2023-10-02T16:15:29.585371          200  sabrina-n-martinez
# 2  2023-10-02T16:15:27.059574          200        seth-siefken
# 3  2023-10-02T16:15:28.912974          200       cayla-shirley
# 4  2023-10-02T16:15:28.647856          200      michael-utecht

# %%
org_query = """
PREFIX wd: <https://geokb.wikibase.cloud/entity/>
PREFIX wdt: <https://geokb.wikibase.cloud/prop/direct/>

SELECT ?item ?itemLabel ?item_alt_label
WHERE {
  # ?item wdt:P62* wd:Q44210 .
  OPTIONAL {
    # ?item skos:altLabel ?item_alt_label .
    FILTER (lang(?item_alt_label)='en')
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
"""

r_orgs = requests.get(
    'https://geokb.wikibase.cloud/query/sparql',
    params = {'query': org_query, 'format': 'json'}
)

df_geokb_orgs = df_from_sparql(r_orgs.json())
df_geokb_orgs['qid'] = df_geokb_orgs['item'].apply(lambda x: x.split('/')[-1])
org_lookup = df_geokb_orgs.set_index('itemLabel')['qid'].to_dict()
org_lookup.update(df_geokb_orgs[df_geokb_orgs['item_alt_label'].notnull()].set_index('item_alt_label')['qid'].to_dict())

org_lookup['Hydrologic Instrumentation Facility (HIF)'] = 'Q44352'
org_lookup['Caribbean-Florida Water Science Center (CFWSC)'] = 'Q44285'
org_lookup['South Atlantic Water Science Center (SAWSC)'] = 'Q44236'
org_lookup['Reston Stable Isotope Laboratory (RSIL)'] = 'Q44350'
org_lookup['Michigan Bacteriological Research Laboratory'] = 'Q50911'
org_lookup['Science Data Management'] = 'Q44223'

# %%
df_missing_profiles['org_qid'] = df_missing_profiles['organization_name'].apply(lambda x: org_lookup[x] if x in org_lookup else None)

# %%
references = geokb.models.References()
references.add(
    geokb.datatypes.Item(
        prop_nr=geokb.prop_lookup['data source'],
        value="Q44323"
    )
)

profile_qualifers = geokb.models.Qualifiers()
profile_qualifers.add(
    geokb.datatypes.Time(
        prop_nr=geokb.prop_lookup['retrieved'],
        time='+2023-10-03T00:00:00Z',
    )
)
profile_qualifers.add(
    geokb.datatypes.String(
        prop_nr=geokb.prop_lookup['status code'],
        value='200'
    )
)

pit_qualifier = geokb.models.Qualifiers()
pit_qualifier.add(
    geokb.datatypes.Time(
        prop_nr=geokb.prop_lookup['point in time'],
        time='+2023-10-03T00:00:00Z',
    )
)

for index, row in df_missing_profiles[df_missing_profiles['name'] != 'Tim Clements'].iterrows():
    item = geokb.wbi.item.new()

    item.labels.set('en', row['name'])
    item.descriptions.set('en', f"{row['title']} at the {row['organization_name']}")

    item.claims.add(
        geokb.datatypes.Item(
            prop_nr=geokb.prop_lookup['instance of'],
            value="Q3",
            references=references
        )
    )

    item.claims.add(
        geokb.datatypes.URL(
            prop_nr=geokb.prop_lookup['reference URL'],
            value=row['url'],
            references=references,
            qualifiers=profile_qualifers
        )
    )
    
    item.claims.add(
        geokb.datatypes.Item(
            prop_nr=geokb.prop_lookup['employer'],
            value="Q44210",
            references=references,
            qualifiers=pit_qualifier
        )
    )

    item.claims.add(
        geokb.datatypes.Item(
            prop_nr=geokb.prop_lookup['affiliation'],
            value=row['org_qid'],
            references=references,
            qualifiers=pit_qualifier
        )
    )

    if row['orcid']:
        item.claims.add(
            geokb.datatypes.ExternalID(
                prop_nr=geokb.prop_lookup['ORCID iD'],
                value=row['orcid'],
                references=references,
                qualifiers=pit_qualifier
            )
        )

    if row['email']:
        item.claims.add(
            geokb.datatypes.URL(
                prop_nr=geokb.prop_lookup['email address'],
                value=f"mailto:{row['email']}",
                references=references,
                qualifiers=pit_qualifier
            )
        )

    try:
        response = item.write(
            summary="Added person item from staff profile inventory"
        )
        new_qid = response.id
        print(row['name'], new_qid)
    except Exception as e:
        print("ERROR", str(e))
        new_qid=False

    if new_qid:
        profile_doc = next((i for i in missing_profiles if i['meta']['url'] == row['url']), None)
        if profile_doc is None:
            print("ERROR: Profile not found")
        else:
            profile_doc = {
                "usgs_staff_profile": profile_doc
            }
            talk_page = mw_site.pages[f"Item_talk:{new_qid}"]
            talk_page.save(yaml.dump(profile_doc), summary='Update cached profile metadata')
            print("Cached profile to talk page")
# Out:
# Sabrina N Martinez Q159659
# Cached profile to talk page
# Seth Siefken Q159660
# Cached profile to talk page
# Cayla Shirley Q159661
# Cached profile to talk page
# Michael Utecht Q159662
# Cached profile to talk page
# Morgan Van Aken Q159663
# Cached profile to talk page
# Courtney Kramer Q159664
# Cached profile to talk page
# Travis Hiett Q159665
# Cached profile to talk page
# Jessica N Middleton Q159666
# Cached profile to talk page
# Eden F. Zickler Q159667
# Cached profile to talk page
# Kenan Matterson Q159668
# Cached profile to talk page
# Harold R Myers Q159669
# Cached profile to talk page
# Cayla Carlson Q159670
# Cached profile to talk page
# Caden P Brege Q159671
# Cached profile to talk page
# Jaycee Favela Q159672
# Cached profile to talk page
# Gary L Rowe, Jr., PhD Q159673
# Cached profile to talk page
# Jennie L Ridgley Q159674
# Cached profile to talk page
# Kelli Baxstrom Q159675
# Cached profile to talk page
# Melvin Bower Q159676
# Cached profile to talk page
# Gregor-Fausto Siegmund, Ph.D. Q159677
# Cached profile to talk page
# Zachary Bunnell Q159678
# Cached profile to talk page
# Anahita Tikku, PhD Q159679
# Cached profile to talk page
# Joshua D Lee Q159680
# Cached profile to talk page
# Jeffery East Q159681
# Cached profile to talk page
# Ariel Doumbouya Q159682
# Cached profile to talk page
# Chad Toussant Q159683
# Cached profile to talk page
# Robert Rosenbauer Q159684
# Cached profile to talk page
# Howard Kochman Q159685
# Cached profile to talk page
# Amy M Brooks Q159686
# Cached profile to talk page
# Jason T. Magnuson, PhD Q159687
# Cached profile to talk page
# Hunter Crates Q159688
# Cached profile to talk page
# Travis R Cronk Q159689
# Cached profile to talk page
# Matt Baker Q159690
# Cached profile to talk page
# Veronica Fritz Q159691
# Cached profile to talk page
# Mike Tanner Q159692
# Cached profile to talk page
# Aaron Murphy Q159693
# Cached profile to talk page
# Margaret Fineagan Q159694
# Cached profile to talk page
# Allison I Kreiley Q159695
# Cached profile to talk page
# Gabrielle Black, PhD Q159696
# Cached profile to talk page
# Kalman Csigi Q159697
# Cached profile to talk page
# Josh von Nonn Q159698
# Cached profile to talk page
# Emily Wei, Ph.D. Q159699
# Cached profile to talk page
# Jeffrey A Hansen Q159700
# Cached profile to talk page
# Alexander R Totten Q159701
# Cached profile to talk page
# Delia Ivanoff Q159702
# Cached profile to talk page
# Vikram Saini Q159703
# Cached profile to talk page
# Fletcher C. Brinkerhoff Q159704
# Cached profile to talk page
# Lillian T. Raz, PhD Q159705
# Cached profile to talk page
# Sylas Daughtrey Q159706
# Cached profile to talk page
# Rachelle Johnson Q159707
# Cached profile to talk page
# Sarken Dressler Q159708
# Cached profile to talk page
# Vanessa Londono Q159709
# Cached profile to talk page
# Jeffery Marso Q159710
# Cached profile to talk page
# G Gray Tappan Q159711
# Cached profile to talk page
# Bill Labiosa, Ph.D. Q159712
# Cached profile to talk page
# Breanna Williams Q159713
# Cached profile to talk page
# Sarah H Kennedy Q159714
# Cached profile to talk page
# Jeremiah Drewel Q159715
# Cached profile to talk page
# Jim Anderton Q159716
# Cached profile to talk page
# Bethany Powhida Q159717
# Cached profile to talk page
# Michael D Scheider Q159718
# Cached profile to talk page
# J. Tod Sandlin Q159719
# Cached profile to talk page
# Kathy Ladner Q159720
# Cached profile to talk page
# Zachary Rand Q159721
# Cached profile to talk page
# Zachary Kelly Q159722
# Cached profile to talk page
# Stephen J Zahniser Q159723
# Cached profile to talk page
# Colin H. Williams Q159724
# Cached profile to talk page
# Shea M Musselman Q159725
# Cached profile to talk page
# Suzanne Van Cooten, Ph.D. Q159726
# Cached profile to talk page
# Francesco Guzzo Q159727
# Cached profile to talk page
# Margaret Avery, PhD Q159728
# Cached profile to talk page
# Samantha M Ewing Q159729
# Cached profile to talk page
# Lance Thornton Q159730
# Cached profile to talk page
# James Albrecht Q159731
# Cached profile to talk page
# Ellie Dalsky Q159732
# Cached profile to talk page
# Teresa Kirschling, Ph.D. Q159733
# Cached profile to talk page
# Tracey Felger Q159734
# Cached profile to talk page
# Sylvia R. Gholson Q159735
# Cached profile to talk page
# Michael Landrum Q159736
# Cached profile to talk page
# Catherine Fargen Q159737
# Cached profile to talk page
# Fred Murphy Q159738
# Cached profile to talk page
# Veronica Larwood Q159739
# Cached profile to talk page
# Sharon K Taylor, D.V.M., Ph.D. Q159740
# Cached profile to talk page
# Kevin J Grimsley, P.E. Q159741
# Cached profile to talk page
# Brian W Anderson Q159742
# Cached profile to talk page
# Kellie Wall, Ph.D. Q159743
# Cached profile to talk page
# Harry M Padbury Q159744
# Cached profile to talk page
# John Hall Q159745
# Cached profile to talk page
# Aaron J Enriquez, Ph.D. Q159746
# Cached profile to talk page
# James L Montoya Q159747
# Cached profile to talk page
# Jason Flaum, PhD Q159748
# Cached profile to talk page
# Alexei R Rose Q159749
# Cached profile to talk page
# Lizzette Meza Q159750
# Cached profile to talk page
# Jacob A Gapczynski Q159751
# Cached profile to talk page
# Chris Laveau Q159752
# Cached profile to talk page
# Alysha Mitchell Q159753
# Cached profile to talk page
# Sean A Lewandoski Q159754
# Cached profile to talk page
# Emily Chapin Q159755
# Cached profile to talk page
# Erin E Brino, M.S. Q159756
# Cached profile to talk page
# Mary E. Torrez Q159757
# Cached profile to talk page
# Lee Eicholtz Q159758
# Cached profile to talk page
# Katherine Marx Q159759
# Cached profile to talk page
# Katherine Trickey Q159760
# Cached profile to talk page
# Scott D Stahl Q159761
# Cached profile to talk page
# Nolan Steiner Q159762
# Cached profile to talk page
# Elizabeth Sangine Q159763
# Cached profile to talk page
# Austin L Kochis Q159764
# Cached profile to talk page
# Catherine Costello Q159765
# Cached profile to talk page
# Sarah L Rappaport Q159766
# Cached profile to talk page
# Patty Matthews Q159767
# Cached profile to talk page
# Rachel Reagan Q159768
# Cached profile to talk page
# Jeremy Malen Q159769
# Cached profile to talk page
# Jaime Kostelnik Q159770
# Cached profile to talk page
# Brian Sauer Q159771
# Cached profile to talk page
# Kyle Y Anderson Q159772
# Cached profile to talk page
# Stephen G O'Brien Q159773
# Cached profile to talk page
# Joshua Beaton Q159774
# Cached profile to talk page
# Corey Sannes Q159775
# Cached profile to talk page
# Brad Liedtke Q159776
# Cached profile to talk page
# Daniel Deeds Q159777
# Cached profile to talk page
# John Allen Q159778
# Cached profile to talk page
# Amanda Anderson Q159779
# Cached profile to talk page
# Robert Osadetz Q159780
# Cached profile to talk page
# Denise M. Levitan, Ph.D. Q159781
# Cached profile to talk page
# Katie V Anweiler, M.S. Q159782
# Cached profile to talk page
# Matthew Moser Q159783
# Cached profile to talk page
# Mary Maxey Q159784
# Cached profile to talk page
# Kyle Landolt Q159785
# Cached profile to talk page
# Skylar A Smith Q159786
# Cached profile to talk page
# Cole Krehbiel Q159787
# Cached profile to talk page
# Noah M Belcher Q159788
# Cached profile to talk page
# Gary Wall Q159789
# Cached profile to talk page
# Amanda Schoen Q159790
# Cached profile to talk page
# Ruth F Schulte Q159791
# Cached profile to talk page
# Audrey Lothspeich Q159792
# Cached profile to talk page
# Laura  M DeMott Q159793
# Cached profile to talk page
# Matthew (Matt) W Dawson, BSc Q159794
# Cached profile to talk page
# Joe M. Battle, Sr. Q159795
# Cached profile to talk page
# Daniel Skulski Q159796
# Cached profile to talk page
# Alicia M Rhoades Q159797
# Cached profile to talk page
# Garron B Ross Q159798
# Cached profile to talk page
# Timothy Steed Q159799
# Cached profile to talk page
# Bojan Milinic Q159800
# Cached profile to talk page
# Dennis Finnegan Q159801
# Cached profile to talk page
# Luke S Sayler Q159802
# Cached profile to talk page
# Carly Maas Q159803
# Cached profile to talk page
# Derek Craig Q159804
# Cached profile to talk page
# Sherry Durst Q159805
# Cached profile to talk page
# Jessica E Daniels Q159806
# Cached profile to talk page
# Skye D Fissette Q159807
# Cached profile to talk page
# Jackson Currie Q159808
# Cached profile to talk page
# Parker Rowland Q159809
# Cached profile to talk page
# Kathy Gonzales Q159810
# Cached profile to talk page
# Ilana Casarez Q159811
# Cached profile to talk page
# Timothy D Oden Q159812
# Cached profile to talk page
# Bill Simonds Q159813
# Cached profile to talk page
# Alexis M Weinnig, PhD Q159814
# Cached profile to talk page
# Adam Birken Q159815
# Cached profile to talk page
# Eric Angel Q159816
# Cached profile to talk page
# Mary C. Benage, Ph.D. Q159817
# Cached profile to talk page
# Patrick Bastien Q159818
# Cached profile to talk page
# Christopher D Markley Q159819
# Cached profile to talk page
# Reid Brown Q159820
# Cached profile to talk page
# Craig A Mobley Q159821
# Cached profile to talk page
# Brian Imig Q159822
# Cached profile to talk page
# Aleeza Wilkins Q159823
# Cached profile to talk page
# Matthew Garcia Q159824
# Cached profile to talk page
# Sophia L Lafond-Hudson Q159825
# Cached profile to talk page
# Justin Reale Q159826
# Cached profile to talk page
# David Soong Q159827
# Cached profile to talk page
# Maxwell O. Reynolds Q159828
# Cached profile to talk page
# Joseph Eisaguirre, Ph.D. Q159829
# Cached profile to talk page
# Mari Titcombe Lee, PhD Q159830
# Cached profile to talk page
# Allen Wayne Lyon Q159831
# Cached profile to talk page
# Michael J Lee Q159832
# Cached profile to talk page
# Betzaida Reyes Q159833
# Cached profile to talk page
# Nathan  Stroh Q159834
# Cached profile to talk page
# Timothy Hayes Q159835
# Cached profile to talk page
# Efren Alvarado Q159836
# Cached profile to talk page
# Tyler G Paladino, Ph.D. Q159837
# Cached profile to talk page
# Schuyler Nardelli, PhD Q159838
# Cached profile to talk page
# Max Schwid Q159839
# Cached profile to talk page
# Elizabeth Marchand Q159840
# Cached profile to talk page
# Matthew A Simmons Q159841
# Cached profile to talk page
# Gari Mayberry Q159842
# Cached profile to talk page
# Luke J Fara Q159843
# Cached profile to talk page
# Marco Bagnardi, Ph.D. Q159844
# Cached profile to talk page
# Melinda Martinez, Ph.D. Q159845
# Cached profile to talk page
# Joseph Vrabel Q159846
# Cached profile to talk page
# Jeremy K Newson Q159847
# Cached profile to talk page
# Wes Flynn, PhD Q159848
# Cached profile to talk page
# Sheri L Priddy Q159849
# Cached profile to talk page
# Liane Minckler Q159850
# Cached profile to talk page
# Aliesha L. Krall Q159851
# Cached profile to talk page
# Emma Krolczyk Q159852
# Cached profile to talk page
# Maria C Berry Q159853
# Cached profile to talk page
# Max Schneider, PhD Q159854
# Cached profile to talk page
# Connor Souchek Q159855
# Cached profile to talk page
# Sandra Bond Q159856
# Cached profile to talk page
# Bernadette Tsosie Q159857
# Cached profile to talk page
# Andrew J Shapiro Q159858
# Cached profile to talk page
# Michael L Gustafson Q159859
# Cached profile to talk page
# Riley O Mummah Q159860
# Cached profile to talk page
# Alyssa De Leon Q159861
# Cached profile to talk page
# Rickey Siggal Q159862
# Cached profile to talk page
# J. Rose Wallick Q159863
# Cached profile to talk page
# Jeramy R Jasmann, Ph.D. Q159864
# Cached profile to talk page
# Mitchell R Weaver Q159865
# Cached profile to talk page
# Benjamin Thorpe Q159866
# Cached profile to talk page
# Evan Lechner Q159867
# Cached profile to talk page
# Garret Welsh Q159868
# Cached profile to talk page
# Joshua Larsen Q159869
# Cached profile to talk page
# Jon Nania Q159870
# Cached profile to talk page
# Chloe D. Gustafson Q159871
# Cached profile to talk page
# Logan Sleezer Q159872
# Cached profile to talk page
# Hailey E Trompeter Q159873
# Cached profile to talk page
# Melanie  Greenfield Q159874
# Cached profile to talk page
# Hunter T Polhemus Q159875
# Cached profile to talk page
# Katharine Graham Dahm, Ph.D. Q159876
# Cached profile to talk page
# Joseph Alday Q159877
# Cached profile to talk page
# Melinda Lohmann Q159878
# Cached profile to talk page
# Sarah Y. Murphy, Ph.D. Q159879
# Cached profile to talk page
# James T Romano Q159880
# Cached profile to talk page
# Antawan T. Patterson Q159881
# Cached profile to talk page
# Chris Lee Q159882
# Cached profile to talk page
# Jeanette M Cruz Q159883
# Cached profile to talk page
# Caroline E. Murphy, AWB® Q159884
# Cached profile to talk page
# Emma Siler Q159885
# Cached profile to talk page
# Grant M. Graves, Ph.D. Q159886
# Cached profile to talk page
# Brenda K Densmore Q159887
# Cached profile to talk page
# John F. Paskievitch Q159888
# Cached profile to talk page
# Felecia Lige Q159889
# Cached profile to talk page
# Molly E Huber Q159890
# Cached profile to talk page
# Scott E. Graham Q159891
# Cached profile to talk page
# Matthew Walker Q159892
# Cached profile to talk page
# Randy M Spitzer Q159893
# Cached profile to talk page
# Lance  Clampitt Q159894
# Cached profile to talk page
# Tyler L Chapman Q159895
# Cached profile to talk page
# Charlotte Riggs, PhD Q159896
# Cached profile to talk page
# Megan McLay Q159897
# Cached profile to talk page
# Sierra R Seibold Q159898
# Cached profile to talk page
# Laura Pianowski Q159899
# Cached profile to talk page
# Stephanie Kula Q159900
# Cached profile to talk page
# Alden T Tilley Q159901
# Cached profile to talk page
# Marla Hood Q159902
# Cached profile to talk page
# Vivien B McNett Q159903
# Cached profile to talk page
# Robert Powell Q159904
# Cached profile to talk page
# Jessica Cicale Q159905
# Cached profile to talk page
# Benjamin  Marcy-Quay Q159906
# Cached profile to talk page
# Ed Puckett Q159907
# Cached profile to talk page
# Margaret E Glasgow Q159908
# Cached profile to talk page
# David Hart Q159909
# Cached profile to talk page
# Ella Samuel Q159910
# Cached profile to talk page
# Kathryn Busby, Ph.D. Q159911
# Cached profile to talk page
# Aaron P. Rinehart Q159912
# Cached profile to talk page
# Christopher S Wright Q159913
# Cached profile to talk page
# Megan Marie Jernigan Q159914
# Cached profile to talk page
# Ramona J Neafie Q159915
# Cached profile to talk page
# Eric J Everman Q159916
# Cached profile to talk page
# Emily C Bedinger Q159917
# Cached profile to talk page
# Anna Maher Q159918
# Cached profile to talk page
# Abel Yap Q159919
# Cached profile to talk page
# Jennifer  Braden Q159920
# Cached profile to talk page
# Brendan Foster Q159921
# Cached profile to talk page
# Jennifer E Katz Q159922
# Cached profile to talk page
# Germaine J. Baron Q159923
# Cached profile to talk page
# Janet S McConnell Q159924
# Cached profile to talk page
# J. Jeremy Webber Q159925
# Cached profile to talk page
# Collin J Roland Q159926
# Cached profile to talk page
# Heidi Bockisch Q159927
# Cached profile to talk page
# Lisa  Faust Q159928
# Cached profile to talk page
# Samantha J Murphy Q159929
# Cached profile to talk page
# Autumn Gibson Q159930
# Cached profile to talk page
# Wendi Young Q159931
# Cached profile to talk page
# Stephanie Dudash Q159932
# Cached profile to talk page
# Todd Anderson Q159933
# Cached profile to talk page
# Itziar Lopez Zandueta Q159934
# Cached profile to talk page
# Raymond Julich Q159935
# Cached profile to talk page
# Rachael Paul-Wilson Q159936
# Cached profile to talk page
# Timothy  J Stagnitta Q159937
# Cached profile to talk page
# Harvie Pollard Q159938
# Cached profile to talk page
# Bryce J McClenney Q159939
# Cached profile to talk page
# Meghan Mccallister Q159940
# Cached profile to talk page
# Priscila Vargas-Babilonia Q159941
# Cached profile to talk page
# Katie J. Baker Q159942
# Cached profile to talk page
# Matthew Meulemans Q159943
# Cached profile to talk page
# Elizabeth (Liz) Ensor Q159944
# Cached profile to talk page
# Misty L Mandas Q159945
# Cached profile to talk page
# Allyson Jason Q159946
# Cached profile to talk page
# Stephen Breen Q159947
# Cached profile to talk page
# Justin K Clause Q159948
# Cached profile to talk page
# Tyson Hatton Q159949
# Cached profile to talk page
# Josie Nevitt Q159950
# Cached profile to talk page
# Leah E. Staub Q159951
# Cached profile to talk page
# Alexandra  Hays Q159952
# Cached profile to talk page
# Emily M. Fort Q159953
# Cached profile to talk page
# Rene Rodriguez Q159954
# Cached profile to talk page
# Elisha “Eli”  K. Moore, Ph.D. Q159955
# Cached profile to talk page
# Nicholas K Waldron, B.S., B.A. Q159956
# Cached profile to talk page
# Gabrielle Kuhlmann Q159957
# Cached profile to talk page
# Eugenia D Lino Q159958
# Cached profile to talk page
# Dee-Ann McCarthy Q159959
# Cached profile to talk page
# Michael Tinker Q159960
# Cached profile to talk page
# Mark R. Wheeler Q159961
# Cached profile to talk page
# Kendell R. Ireland Q159962
# Cached profile to talk page
# Annett Sullivan Q159963
# Cached profile to talk page
# Shannon Pace Q159964
# Cached profile to talk page
# Mikael P Hiestand, Ph.D. Q159965
# Cached profile to talk page
# Carrie Huitger Q159966
# Cached profile to talk page
# Oronde Drakes Q159967
# Cached profile to talk page
# Josh Takacs Q159968
# Cached profile to talk page
# Daniel K Blankenship Q159969
# Cached profile to talk page
# Julie Voelschow Q159970
# Cached profile to talk page
# Josh Larson Q159971
# Cached profile to talk page
# Allison Atkinson Q159972
# Cached profile to talk page
# Jennifer M Morris Q159973
# Cached profile to talk page
# Emily H Majcher, PE Q159974
# Cached profile to talk page
# Joseph M Gravino, Jr. Q159975
# Cached profile to talk page
# Vincent Brown Q159976
# Cached profile to talk page
# Laurie Zielinski Q159977
# Cached profile to talk page
# Justin Birchler Q159978
# Cached profile to talk page
# Valeria  A Rodriguez Q159979
# Cached profile to talk page
# Michael S Gross Q159980
# Cached profile to talk page
# Hugh  O Edwards Q159981
# Cached profile to talk page
# Tenielle Gaither Q159982
# Cached profile to talk page
# Sean G Harris Q159983
# Cached profile to talk page
# John M Meyer Q159984
# Cached profile to talk page
# Keith  Grabner Q159985
# Cached profile to talk page
# Shannon Beliew Q159986
# Cached profile to talk page
# Sierra K. Bloomer Q159987
# Cached profile to talk page
# Jay Choi Q159988
# Cached profile to talk page
# Travis M. Knight Q159989
# Cached profile to talk page
# Jo-Ann Dominique Q159990
# Cached profile to talk page
# Adam  A Perez, Ph.D. Q159991
# Cached profile to talk page
# Alex L Stoneburner Q159992
# Cached profile to talk page
# Meagan G Froeba Q159993
# Cached profile to talk page
# Beth  A. Bartel Q159994
# Cached profile to talk page
# Jana Pursley Q159995
# Cached profile to talk page
# Monica Haw Q159996
# Cached profile to talk page
# Keith Bouma-Gregson, PhD Q159997
# Cached profile to talk page
# Bryan G Bonham Q159998
# Cached profile to talk page
# MacKenzie Mills Q159999
# Cached profile to talk page
# William Werkheiser Q160000
# Cached profile to talk page
# Scott C Dwyer Q160001
# Cached profile to talk page
# Jeffrey Rowan Q160002
# Cached profile to talk page
# Benjamin Galbraith Q160003
# Cached profile to talk page
# Raya Pauling Q160004
# Cached profile to talk page
# Michelle Funk Q160005
# Cached profile to talk page
# Rhonda G Aton Q160006
# Cached profile to talk page
# Victoria D. Benitez Q160007
# Cached profile to talk page
# Charles F Wahl Q160008
# Cached profile to talk page
# Michael F Meyer, PhD Q160009
# Cached profile to talk page
# Wallace Jack Greene Q160010
# Cached profile to talk page
# Isaac S Moening-Swanson Q160011
# Cached profile to talk page
# A. Rae Ann Orkild-Norton Q160012
# Cached profile to talk page
# Kurt Schmidt Q160013
# Cached profile to talk page
# Stephanie Perkins Q160014
# Cached profile to talk page
# Laura Labriola Q160015
# Cached profile to talk page
# Summer Praetorius, PhD Q160016
# Cached profile to talk page
# Travis Adams Q160017
# Cached profile to talk page
# C. Justin Mayers Q160018
# Cached profile to talk page
# Stephanie McAfee, Ph.D. Q160019
# Cached profile to talk page
# Michael A Manning Q160020
# Cached profile to talk page
# Hannah M Thompson, PhD Q160021
# Cached profile to talk page
# Ashlyn C Beatty Q160022
# Cached profile to talk page
# David Lesmes Q160023
# Cached profile to talk page
# Alec R. Weisser Q160024
# Cached profile to talk page
# August Schultz Q160025
# Cached profile to talk page
# Briar H Goldwyn, Ph.D. Q160026
# Cached profile to talk page
# Johanna M Nifosi Q160027
# Cached profile to talk page
# Doug Choy Q160028
# Cached profile to talk page
# Benjamin S Leonhardt Q160029
# Cached profile to talk page
# Colton Medler Q160030
# Cached profile to talk page
# Erika Geiger, Ph.D. Q160031
# Cached profile to talk page
# Catherine Christenson Q160032
# Cached profile to talk page
# Mia Dicianna Q160033
# Cached profile to talk page
# Sabrina Sevilgen Q160034
# Cached profile to talk page
# Anthony W Rondon Q160035
# Cached profile to talk page
# Jeffrey M Elliott Q160036
# Cached profile to talk page
# Andreas P Wion Q160037
# Cached profile to talk page
# Waylon Marler Q160038
# Cached profile to talk page
# Rose Pejman Q160039
# Cached profile to talk page
# Gericke Cook Q160040
# Cached profile to talk page
# Denis Sun Q160041
# Cached profile to talk page
# Cory O Brant, PhD Q160042
# Cached profile to talk page
# Alexander A Gray Q160043
# Cached profile to talk page
# David M Coburn Q160044
# Cached profile to talk page
# Narcyz Dubicki, Jr. Q160045
# Cached profile to talk page
# Cordell Johnson Q160046
# Cached profile to talk page
# Sara Piccolomini Q160047
# Cached profile to talk page
# Melanie Steinkamp Q160048
# Cached profile to talk page
# Robert Tusso Q160049
# Cached profile to talk page
# Richard B Castro Q160050
# Cached profile to talk page
# Eric J Reiss Q160051
# Cached profile to talk page
# Robin Moore Q160052
# Cached profile to talk page
# Michelle Collier Q160053
# Cached profile to talk page
# Megan A Evans Q160054
# Cached profile to talk page
# Alma C Schrage Q160055
# Cached profile to talk page
# Harold Cameron Q160056
# Cached profile to talk page
# Lynda Lastowka Q160057
# Cached profile to talk page
