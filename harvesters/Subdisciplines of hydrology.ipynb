# %% [markdown]
# This notebook works through an experimental process for building out a section of "class items" in the GeoKB based on some level of thoughtful processing from a Wikidata source. As in other cases, I am leveraging the fact that we are basing our knowledgebase within a Mediawiki instance to use the simplicity of wiki pages to house important details about what we are assembling in the GeoKB. Here, we are building subdisciplines of the broader scientific field of hydrology. We get some source data from Wikidata, refine it in OpenRefine, and then cache it to the wiki page for the "superclass" item, hydrology, for later processing into new and improved GeoKB items. While we could push these changes directly from an OpenRefine instance, some of the details are not captured in a way that we can point to as provenance and build upon for other use cases. This is an alternative pathway that we'll examine in more complex use cases to determine its utillity.

# %%
import pandas as pd
from wbmaker import WikibaseConnection
import pytablewriter
import json
import yaml

geokb = WikibaseConnection('GEOKB_CLOUD')

# %% [markdown]
# # Get raw source from Wikidata
# Here we pull raw source data that we worked through OpenRefine and convert it to a Mediawiki table that will render as HTML in the wiki page. This has the effect of caching a point-in-time snapshot of the content we leveraged from Wikidata.

# %%
wd_hydrology_query = """
SELECT ?item ?itemLabel ?itemDescription ?practiced_by ?practiced_byLabel ?practiced_byDescription ?subclass_of ?subclass_ofLabel
WHERE {
  # ?item wdt:P279* wd:Q42250 .
  # ?item wdt:P279 ?subclass_of .
  OPTIONAL {
    # ?item wdt:P3095 ?practiced_by .
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""

wd_hydrology = geokb.sparql_query(
    query=wd_hydrology_query,
    endpoint='https://query.wikidata.org/sparql'
)

raw_table_writer = pytablewriter.MediaWikiTableWriter()
raw_table_writer.from_dataframe(wd_hydrology)
raw_table = raw_table_writer.dumps()

# %% [markdown]
# # Get processed source from cache
# There might eventually be a better programmatic way to do this, but for now I dump the refined data table to CSV and then import it here and convert to a Mediawiki markdown table that will render as HTML and be readable with Pandas.

# %%
refined_hydrology_subclasses = pd.read_csv('../../../../Downloads/hydrology-subclasses.csv')
refined_hydrology_subclasses.fillna('', inplace=True)

processed_table_writer = pytablewriter.MediaWikiTableWriter()
processed_table_writer.from_dataframe(refined_hydrology_subclasses)
processed_table = processed_table_writer.dumps()

# %% [markdown]
# # Get processing history
# There might eventually be a better programmatic way to do this, but for now I dump the processing history from OpenRefine to its raw JSON form and then convert that to YAML so we can stash it in the item talk page.

# %%
with open('../../../../Downloads/history.json') as f:
    processing_history = yaml.safe_dump(json.load(f), sort_keys=False)

# %% [markdown]
# # Write to wiki page

# %%
hydrology_item_talk = 'Item_talk:Q158992'
hydrology_page = geokb.mw_site.pages[hydrology_item_talk]

# %%
# Write the final processed data from the cache as the first table on the page
hydrology_page.save(
    processed_table, 
    section="new", 
    summary="Source Data"
)

# Write the Wikidata query used
hydrology_page.save(
    "<sparql>" + wd_hydrology_query + "</sparql>", 
    section="new", 
    summary="Wikidata Query"
)

# Write the raw data from Wikidata
hydrology_page.save(
    raw_table, 
    section="new", 
    summary="Raw Wikidata"
)

# Write the processing history as YAML
hydrology_page.save(
    processing_history, 
    section="new", 
    summary="Processing History"
)
# Out:
# OrderedDict([('result', 'Success'),
#              ('pageid', 213746),
#              ('title', 'Item talk:Q158992'),
#              ('contentmodel', 'wikitext'),
#              ('oldrevid', 492783),
#              ('newrevid', 492784),
#              ('newtimestamp', '2023-10-23T12:14:36Z'),
#              ('watched', '')])

# %% [markdown]
# # Process items and claims
# The following is something I could refine into a standard pipeline to take something like the source table I produced which has information about new science disciplines, types of scientists, and the connections between them to build items within the GeoKB. The same basic logic could apply to anything with this kind of relationship. For now, there were a couple of specialized things I needed to handle in the following code, so I'll revisit and improve on this with the next case.

# %%
hydrology_fields_source = pd.read_html(f'https://geokb.wikibase.cloud/wiki/{hydrology_item_talk}')[0]
hydrology_fields_source.head()
# Out:
#                                      item       itemLabel  \
# 0   http://www.wikidata.org/entity/Q42250       hydrology
# 1  http://www.wikidata.org/entity/Q179509    hydrogeology
# 2  http://www.wikidata.org/entity/Q179509    hydrogeology
# 3  http://www.wikidata.org/entity/Q912065  hydrochemistry
# 4  http://www.wikidata.org/entity/Q912065  hydrochemistry
#
#   geokb_discipline_qid                                    itemDescription  \
# 0              Q158992  science that deals with the water above, on an...
# 1              Q158991  branch of science that studies distribution an...
# 2              Q158991  branch of science that studies distribution an...
# 3                  NaN  branch of hydrology that deals with the chemic...
# 4                  NaN  branch of hydrology that deals with the chemic...
#
#                                 practiced_by practiced_byLabel  \
# 0    http://www.wikidata.org/entity/Q3644587       hydrologist
# 1   http://www.wikidata.org/entity/Q35380338    hydrogeologist
# 2   http://www.wikidata.org/entity/Q35380338    hydrogeologist
# 3  http://www.wikidata.org/entity/Q110624867      hydrochemist
# 4  http://www.wikidata.org/entity/Q110624867      hydrochemist
#
#   geokb_profession_qid                            practiced_byDescription  \
# 0              Q159575                 earth scientist that studies water
# 1              Q159638          earth scientist that studies ground water
# 2              Q159638          earth scientist that studies ground water
# 3                  NaN  earth scientist who studies the chemical chara...
# 4                  NaN  earth scientist who studies the chemical chara...
#
#                               subclass_of subclass_ofLabel  \
# 0     http://www.wikidata.org/entity/Q336   earth sciences
# 1    http://www.wikidata.org/entity/Q1069          geology
# 2   http://www.wikidata.org/entity/Q42250        hydrology
# 3   http://www.wikidata.org/entity/Q42250        hydrology
# 4  http://www.wikidata.org/entity/Q161764     geochemistry
#
#   geokb_superclass_qid
# 0              Q158971
# 1              Q158984
# 2              Q158992
# 3              Q158992
# 4              Q158980

# %%
practiced_by_query = """
PREFIX wdt: <https://geokb.wikibase.cloud/prop/direct/>

SELECT ?item ?itemLabel ?practiced_by ?practiced_byLabel
WHERE {
  # ?item wdt:P158 ?practiced_by .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
"""

practiced_by = geokb.sparql_query(practiced_by_query)
practiced_by['geokb_superclass_qid'] = practiced_by['item'].apply(lambda x: x.split('/')[-1])
practiced_by['practiced_by_parent'] = practiced_by['practiced_by'].apply(lambda x: x.split('/')[-1])

# %%
geokb_practiced_by_merge = pd.merge(
    left=hydrology_fields_source,
    right=practiced_by[['geokb_superclass_qid', 'practiced_by_parent']],
    how='left',
    on='geokb_superclass_qid'
)

# %%
geokb_practiced_by_merge
# Out:
#                                          item                itemLabel  \
# 0       http://www.wikidata.org/entity/Q42250                hydrology
# 1      http://www.wikidata.org/entity/Q179509             hydrogeology
# 2      http://www.wikidata.org/entity/Q179509             hydrogeology
# 3      http://www.wikidata.org/entity/Q912065           hydrochemistry
# 4      http://www.wikidata.org/entity/Q912065           hydrochemistry
# 5     http://www.wikidata.org/entity/Q2330259               potamology
# 6     http://www.wikidata.org/entity/Q2363192             ecohydrology
# 7     http://www.wikidata.org/entity/Q2363192             ecohydrology
# 8     http://www.wikidata.org/entity/Q2883300   agricultural hydrology
# 9     http://www.wikidata.org/entity/Q2883300   agricultural hydrology
# 10    http://www.wikidata.org/entity/Q3143834             hydroecology
# 11    http://www.wikidata.org/entity/Q3143834             hydroecology
# 12    http://www.wikidata.org/entity/Q3743777              telmatology
# 13    http://www.wikidata.org/entity/Q3743777              telmatology
# 14    http://www.wikidata.org/entity/Q4400371         river morphology
# 15    http://www.wikidata.org/entity/Q4400371         river morphology
# 16    http://www.wikidata.org/entity/Q5051759      catchment hydrology
# 17    http://www.wikidata.org/entity/Q7548407           snow hydrology
# 18   http://www.wikidata.org/entity/Q10295440    statistical hydrology
# 19   http://www.wikidata.org/entity/Q10295440    statistical hydrology
# 20   http://www.wikidata.org/entity/Q13416553        Isotope hydrology
# 21   http://www.wikidata.org/entity/Q20638505       hydrogeomorphology
# 22   http://www.wikidata.org/entity/Q20638505       hydrogeomorphology
# 23   http://www.wikidata.org/entity/Q63571124          palaeohydrology
# 24   http://www.wikidata.org/entity/Q63571124          palaeohydrology
# 25   http://www.wikidata.org/entity/Q65235465    fluvial geomorphology
# 26  http://www.wikidata.org/entity/Q102073785  fault zone hydrogeology
# 27  http://www.wikidata.org/entity/Q105552831         forest hydrology
# 28  http://www.wikidata.org/entity/Q105552831         forest hydrology
# 29  http://www.wikidata.org/entity/Q110968692      watershed hydrology
# 30  http://www.wikidata.org/entity/Q110968692      watershed hydrology
# 31  http://www.wikidata.org/entity/Q111327099          urban hydrology
# 32  http://www.wikidata.org/entity/Q115827802     coastal hydrogeology
#
#    geokb_discipline_qid                                    itemDescription  \
# 0               Q158992  science that deals with the water above, on an...
# 1               Q158991  branch of science that studies distribution an...
# 2               Q158991  branch of science that studies distribution an...
# 3                   NaN  branch of hydrology that deals with the chemic...
# 4                   NaN  branch of hydrology that deals with the chemic...
# 5                   NaN               study of rivers; branch of geography
# 6                   NaN  interdisciplinary field studying the interacti...
# 7                   NaN  interdisciplinary field studying the interacti...
# 8                   NaN  study of water balance components intervening ...
# 9                   NaN  study of water balance components intervening ...
# 10                  NaN  the linking of knowledge from hydrological, hy...
# 11                  NaN  the linking of knowledge from hydrological, hy...
# 12                  NaN  branch of physical geography concerned with th...
# 13                  NaN  branch of physical geography concerned with th...
# 14                  NaN  change in shape and direction of river channel...
# 15                  NaN  change in shape and direction of river channel...
# 16                  NaN  hydrology of catchments, areas where water is ...
# 17                  NaN  field of snow science concerning its compositi...
# 18                  NaN  branch of hydrology that uses mathematical and...
# 19                  NaN  branch of hydrology that uses mathematical and...
# 20                  NaN  field of geochemistry and hydrology that uses ...
# 21                  NaN  interaction and linkage of hydrologic processe...
# 22                  NaN  interaction and linkage of hydrologic processe...
# 23                  NaN    study of water courses from the geological past
# 24                  NaN    study of water courses from the geological past
# 25                  NaN  study of how flowing water shapes and modifies...
# 26                  NaN      study of how deformed rocks alter fluid flows
# 27                  NaN  branch of science that combines aspects of hyd...
# 28                  NaN  branch of science that combines aspects of hyd...
# 29                  NaN  study of how water flows across a watershed, w...
# 30                  NaN  study of how water flows across a watershed, w...
# 31                  NaN  scientific study of the hydrological cycle wit...
# 32                  NaN  branch of hydrogeology that focuses on the mov...
#
#                                  practiced_by   practiced_byLabel  \
# 0     http://www.wikidata.org/entity/Q3644587         hydrologist
# 1    http://www.wikidata.org/entity/Q35380338      hydrogeologist
# 2    http://www.wikidata.org/entity/Q35380338      hydrogeologist
# 3   http://www.wikidata.org/entity/Q110624867        hydrochemist
# 4   http://www.wikidata.org/entity/Q110624867        hydrochemist
# 5   http://www.wikidata.org/entity/Q107448718        potamologist
# 6   http://www.wikidata.org/entity/Q113057726      ecohydrologist
# 7   http://www.wikidata.org/entity/Q113057726      ecohydrologist
# 8                                         NaN                 NaN
# 9                                         NaN                 NaN
# 10  http://www.wikidata.org/entity/Q101508301      hydroecologist
# 11  http://www.wikidata.org/entity/Q101508301      hydroecologist
# 12                                        NaN                 NaN
# 13                                        NaN                 NaN
# 14                                        NaN                 NaN
# 15                                        NaN                 NaN
# 16                                        NaN                 NaN
# 17                                        NaN                 NaN
# 18                                        NaN                 NaN
# 19                                        NaN                 NaN
# 20                                        NaN                 NaN
# 21                                        NaN                 NaN
# 22                                        NaN                 NaN
# 23                                        NaN                 NaN
# 24                                        NaN                 NaN
# 25                                        NaN                 NaN
# 26                                        NaN                 NaN
# 27  http://www.wikidata.org/entity/Q105552827  forest hydrologist
# 28  http://www.wikidata.org/entity/Q105552827  forest hydrologist
# 29                                        NaN                 NaN
# 30                                        NaN                 NaN
# 31                                        NaN                 NaN
# 32                                        NaN                 NaN
#
#    geokb_profession_qid                            practiced_byDescription  \
# 0               Q159575                 earth scientist that studies water
# 1               Q159638          earth scientist that studies ground water
# 2               Q159638          earth scientist that studies ground water
# 3                   NaN  earth scientist who studies the chemical chara...
# 4                   NaN  earth scientist who studies the chemical chara...
# 5                   NaN                    hydrologist that studies rivers
# 6                   NaN  interdisciplinary scientist studying the inter...
# 7                   NaN  interdisciplinary scientist studying the inter...
# 8                   NaN                                                NaN
# 9                   NaN                                                NaN
# 10                  NaN  researcher at the interface between the hydrol...
# 11                  NaN  researcher at the interface between the hydrol...
# 12                  NaN                                                NaN
# 13                  NaN                                                NaN
# 14                  NaN                                                NaN
# 15                  NaN                                                NaN
# 16                  NaN                                                NaN
# 17                  NaN                                                NaN
# 18                  NaN                                                NaN
# 19                  NaN                                                NaN
# 20                  NaN                                                NaN
# 21                  NaN                                                NaN
# 22                  NaN                                                NaN
# 23                  NaN                                                NaN
# 24                  NaN                                                NaN
# 25                  NaN                                                NaN
# 26                  NaN                                                NaN
# 27                  NaN  earth scientist who gathers and analyzes infor...
# 28                  NaN  earth scientist who gathers and analyzes infor...
# 29                  NaN                                                NaN
# 30                  NaN                                                NaN
# 31                  NaN                                                NaN
# 32                  NaN                                                NaN
#
#                                   subclass_of  subclass_ofLabel  \
# 0         http://www.wikidata.org/entity/Q336    earth sciences
# 1        http://www.wikidata.org/entity/Q1069           geology
# 2       http://www.wikidata.org/entity/Q42250         hydrology
# 3       http://www.wikidata.org/entity/Q42250         hydrology
# 4      http://www.wikidata.org/entity/Q161764      geochemistry
# 5       http://www.wikidata.org/entity/Q42250         hydrology
# 6        http://www.wikidata.org/entity/Q7150           ecology
# 7       http://www.wikidata.org/entity/Q42250         hydrology
# 8       http://www.wikidata.org/entity/Q42250         hydrology
# 9      http://www.wikidata.org/entity/Q396152         hydrology
# 10       http://www.wikidata.org/entity/Q7150           ecology
# 11      http://www.wikidata.org/entity/Q42250         hydrology
# 12      http://www.wikidata.org/entity/Q42250         hydrology
# 13      http://www.wikidata.org/entity/Q52107         geography
# 14      http://www.wikidata.org/entity/Q52109     geomorphology
# 15   http://www.wikidata.org/entity/Q65235465     geomorphology
# 16      http://www.wikidata.org/entity/Q42250         hydrology
# 17      http://www.wikidata.org/entity/Q42250         hydrology
# 18      http://www.wikidata.org/entity/Q12483        statistics
# 19      http://www.wikidata.org/entity/Q42250         hydrology
# 20      http://www.wikidata.org/entity/Q42250         hydrology
# 21      http://www.wikidata.org/entity/Q42250         hydrology
# 22      http://www.wikidata.org/entity/Q52109     geomorphology
# 23       http://www.wikidata.org/entity/Q7205      paleontology
# 24      http://www.wikidata.org/entity/Q42250         hydrology
# 25   http://www.wikidata.org/entity/Q20638505     geomorphology
# 26     http://www.wikidata.org/entity/Q179509      hydrogeology
# 27      http://www.wikidata.org/entity/Q42250         hydrology
# 28   http://www.wikidata.org/entity/Q19924411  forestry science
# 29      http://www.wikidata.org/entity/Q42250         hydrology
# 30  http://www.wikidata.org/entity/Q105277236         hydrology
# 31      http://www.wikidata.org/entity/Q42250         hydrology
# 32     http://www.wikidata.org/entity/Q179509      hydrogeology
#
#    geokb_superclass_qid practiced_by_parent
# 0               Q158971             Q159571
# 1               Q158984             Q159572
# 2               Q158992             Q159575
# 3               Q158992             Q159575
# 4               Q158980             Q159577
# 5               Q158992             Q159575
# 6               Q158972             Q159589
# 7               Q158992             Q159575
# 8               Q158992             Q159575
# 9               Q158992             Q159575
# 10              Q158972             Q159589
# 11              Q158992             Q159575
# 12              Q158992             Q159575
# 13              Q158983             Q159573
# 14              Q158985             Q159578
# 15              Q158985             Q159578
# 16              Q158992             Q159575
# 17              Q158992             Q159575
# 18              Q161190             Q161193
# 19              Q158992             Q159575
# 20              Q158992             Q159575
# 21              Q158992             Q159575
# 22              Q158985             Q159578
# 23              Q159017             Q159579
# 24              Q158992             Q159575
# 25              Q158985             Q159578
# 26              Q158991             Q159638
# 27              Q158992             Q159575
# 28              Q161191                 NaN
# 29              Q158992             Q159575
# 30              Q158992             Q159575
# 31              Q158992             Q159575
# 32              Q158991             Q159638

# %%
new_scientist_classes = geokb_practiced_by_merge[
    geokb_practiced_by_merge['geokb_profession_qid'].isnull()
    &
    geokb_practiced_by_merge['practiced_by_parent'].notnull()
][
    [
        'practiced_by',
        'practiced_byLabel',
        'practiced_byDescription',
        'practiced_by_parent'
    ]
].groupby(['practiced_by', 'practiced_byLabel', 'practiced_byDescription'], as_index=False)['practiced_by_parent'].agg(list)

new_scientist_classes
# Out:
#                                 practiced_by   practiced_byLabel  \
# 0  http://www.wikidata.org/entity/Q101508301      hydroecologist
# 1  http://www.wikidata.org/entity/Q105552827  forest hydrologist
# 2  http://www.wikidata.org/entity/Q107448718        potamologist
# 3  http://www.wikidata.org/entity/Q110624867        hydrochemist
# 4  http://www.wikidata.org/entity/Q113057726      ecohydrologist
#
#                              practiced_byDescription practiced_by_parent
# 0  researcher at the interface between the hydrol...  [Q159589, Q159575]
# 1  earth scientist who gathers and analyzes infor...           [Q159575]
# 2                    hydrologist that studies rivers           [Q159575]
# 3  earth scientist who studies the chemical chara...  [Q159575, Q159577]
# 4  interdisciplinary scientist studying the inter...  [Q159589, Q159575]

# %%
new_scientist_classes_qids = []

for _, row in new_scientist_classes.iterrows():
    item = geokb.wbi.item.new()
    item.labels.set('en', row['practiced_byLabel'])
    item.descriptions.set('en', row['practiced_byDescription'])

    subclass_claims = []
    for parent_qid in row['practiced_by_parent']:
        subclass_claims.append(
            geokb.datatypes.Item(
                prop_nr=geokb.prop_lookup['subclass of'],
                value=parent_qid
            )
        )
    item.claims.add(subclass_claims)

    item.claims.add(
        geokb.datatypes.URL(
            prop_nr=geokb.prop_lookup['same as'],
            value=row['practiced_by']
        )
    )

    response = item.write(
        summary="Added new class of scientist for hydrology-related fields from Wikidata source"
    )
    new_scientist_classes_qids.append({
        'qid': response.id,
        'label': row['practiced_byLabel']
    })
    print(response.id, row['practiced_byLabel'])
# Out:
# Q161195 hydroecologist
# Q161196 forest hydrologist
# Q161197 potamologist
# Q161198 hydrochemist
# Q161199 ecohydrologist

# %%
new_science_classes = geokb_practiced_by_merge[
    geokb_practiced_by_merge['geokb_discipline_qid'].isnull()
][
    [
        'item',
        'itemLabel',
        'itemDescription',
        'geokb_superclass_qid'
    ]
].groupby(['item', 'itemLabel', 'itemDescription'], as_index=False)['geokb_superclass_qid'].agg(list)

new_science_classes
# Out:
#                                          item                itemLabel  \
# 0   http://www.wikidata.org/entity/Q102073785  fault zone hydrogeology
# 1    http://www.wikidata.org/entity/Q10295440    statistical hydrology
# 2   http://www.wikidata.org/entity/Q105552831         forest hydrology
# 3   http://www.wikidata.org/entity/Q110968692      watershed hydrology
# 4   http://www.wikidata.org/entity/Q111327099          urban hydrology
# 5   http://www.wikidata.org/entity/Q115827802     coastal hydrogeology
# 6    http://www.wikidata.org/entity/Q13416553        Isotope hydrology
# 7    http://www.wikidata.org/entity/Q20638505       hydrogeomorphology
# 8     http://www.wikidata.org/entity/Q2330259               potamology
# 9     http://www.wikidata.org/entity/Q2363192             ecohydrology
# 10    http://www.wikidata.org/entity/Q2883300   agricultural hydrology
# 11    http://www.wikidata.org/entity/Q3143834             hydroecology
# 12    http://www.wikidata.org/entity/Q3743777              telmatology
# 13    http://www.wikidata.org/entity/Q4400371         river morphology
# 14    http://www.wikidata.org/entity/Q5051759      catchment hydrology
# 15   http://www.wikidata.org/entity/Q63571124          palaeohydrology
# 16   http://www.wikidata.org/entity/Q65235465    fluvial geomorphology
# 17    http://www.wikidata.org/entity/Q7548407           snow hydrology
# 18     http://www.wikidata.org/entity/Q912065           hydrochemistry
#
#                                       itemDescription geokb_superclass_qid
# 0       study of how deformed rocks alter fluid flows            [Q158991]
# 1   branch of hydrology that uses mathematical and...   [Q161190, Q158992]
# 2   branch of science that combines aspects of hyd...   [Q158992, Q161191]
# 3   study of how water flows across a watershed, w...   [Q158992, Q158992]
# 4   scientific study of the hydrological cycle wit...            [Q158992]
# 5   branch of hydrogeology that focuses on the mov...            [Q158991]
# 6   field of geochemistry and hydrology that uses ...            [Q158992]
# 7   interaction and linkage of hydrologic processe...   [Q158992, Q158985]
# 8                study of rivers; branch of geography            [Q158992]
# 9   interdisciplinary field studying the interacti...   [Q158972, Q158992]
# 10  study of water balance components intervening ...   [Q158992, Q158992]
# 11  the linking of knowledge from hydrological, hy...   [Q158972, Q158992]
# 12  branch of physical geography concerned with th...   [Q158992, Q158983]
# 13  change in shape and direction of river channel...   [Q158985, Q158985]
# 14  hydrology of catchments, areas where water is ...            [Q158992]
# 15    study of water courses from the geological past   [Q159017, Q158992]
# 16  study of how flowing water shapes and modifies...            [Q158985]
# 17  field of snow science concerning its compositi...            [Q158992]
# 18  branch of hydrology that deals with the chemic...   [Q158992, Q158980]

# %%
new_science_classes_qids = []

for _, row in new_science_classes.iterrows():
    item = geokb.wbi.item.new()
    item.labels.set('en', row['itemLabel'])
    item.descriptions.set('en', row['itemDescription'])

    subclass_claims = []
    for parent_qid in row['geokb_superclass_qid']:
        subclass_claims.append(
            geokb.datatypes.Item(
                prop_nr=geokb.prop_lookup['subclass of'],
                value=parent_qid
            )
        )
    item.claims.add(subclass_claims)

    item.claims.add(
        geokb.datatypes.URL(
            prop_nr=geokb.prop_lookup['same as'],
            value=row['item']
        )
    )

    response = item.write(
        summary="Added new scientific discipline for hydrology-related fields from Wikidata source"
    )
    new_science_classes_qids.append({
        'qid': response.id,
        'label': row['itemLabel']
    })
    print(response.id, row['itemLabel'])
# Out:
# Q161200 fault zone hydrogeology
# Q161201 statistical hydrology
# Q161202 forest hydrology
# Q161203 watershed hydrology
# Q161204 urban hydrology
# Q161205 coastal hydrogeology
# Q161206 Isotope hydrology
# Q161207 hydrogeomorphology
# Q161208 potamology
# Q161209 ecohydrology
# Q161210 agricultural hydrology
# Q161211 hydroecology
# Q161212 telmatology
# Q161213 river morphology
# Q161214 catchment hydrology
# Q161215 palaeohydrology
# Q161216 fluvial geomorphology
# Q161217 snow hydrology
# Q161218 hydrochemistry

# %%
discipline_qid_lookup = pd.DataFrame(new_science_classes_qids).set_index('label')['qid'].to_dict()
profession_qid_lookup = pd.DataFrame(new_scientist_classes_qids).set_index('label')['qid'].to_dict()

# %%
practitioner_mapping = geokb_practiced_by_merge[geokb_practiced_by_merge['geokb_discipline_qid'].isnull()][['itemLabel','practiced_byLabel']].reset_index(drop=True)
practitioner_mapping['discipline_qid'] = practitioner_mapping['itemLabel'].apply(lambda x: discipline_qid_lookup[x])
practitioner_mapping['profession_qid'] = practitioner_mapping['practiced_byLabel'].apply(lambda x: profession_qid_lookup[x] if x in profession_qid_lookup else 'Q159575')

# %%
for _, row in practitioner_mapping[['discipline_qid', 'profession_qid']].groupby('discipline_qid', as_index=False)['profession_qid'].agg(list).iterrows():
    item = geokb.wbi.item.get(row['discipline_qid'])
    practiced_by_claims = []
    for profession_qid in row['profession_qid']:
        practiced_by_claims.append(
            geokb.datatypes.Item(
                prop_nr=geokb.prop_lookup['practiced by'],
                value=profession_qid
            )
        )
    item.claims.add(practiced_by_claims, action_if_exists=geokb.action_if_exists.REPLACE_ALL)
    response = item.write(
        summary="Added new practitioner mapping for hydrology-related fields from Wikidata source"
    )
    print(response.id)
# Out:
# Q161200
# Q161201
# Q161202
# Q161203
# Q161204
# Q161205
# Q161206
# Q161207
# Q161208
# Q161209
# Q161210
# Q161211
# Q161212
# Q161213
# Q161214
# Q161215
# Q161216
# Q161217
# Q161218

# %%
for _, row in practitioner_mapping[practitioner_mapping['profession_qid'] != 'Q159575'][['discipline_qid', 'profession_qid']].groupby('profession_qid', as_index=False)['discipline_qid'].agg(list).iterrows():
    item = geokb.wbi.item.get(row['profession_qid'])
    practioner_claims = []
    for discipline_qid in row['discipline_qid']:
        practioner_claims.append(
            geokb.datatypes.Item(
                prop_nr=geokb.prop_lookup['practitioner of'],
                value=discipline_qid
            )
        )
    item.claims.add(practioner_claims, action_if_exists=geokb.action_if_exists.REPLACE_ALL)
    response = item.write(
        summary="Added new practitioner mapping for hydrology-related fields from Wikidata source"
    )
    print(response.id)
# Out:
# Q161195
# Q161196
# Q161197
# Q161198
# Q161199
