# %%
import rdflib
import pandas as pd
import re
from wbmaker import WikibaseConnection

geokb = WikibaseConnection('GEOKB_CLOUD')

# %% [markdown]
# # Current GeoKB Classes

# %%
geokb_rock_query = """
PREFIX wd: <https://geokb.wikibase.cloud/entity/>
PREFIX wdt: <https://geokb.wikibase.cloud/prop/direct/>

SELECT ?rock ?rockLabel ?rockDescription ?subClassOf ?subClassOfLabel ?same_as
WHERE {
  # ?rock wdt:P2* wd:Q41261 ;
        wdt:P2 ?subClassOf .
  OPTIONAL {
    # ?rock wdt:P84 ?same_as .
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
"""

geokb_rocks = geokb.sparql_query(geokb_rock_query)
geokb_rocks['rock_qid'] = geokb_rocks['rock'].apply(lambda x: x.split('/')[-1])
geokb_rocks['subclass_qid'] = geokb_rocks['subClassOf'].apply(lambda x: x.split('/')[-1])

geokb_rocks = geokb_rocks.groupby(['rock_qid','rockLabel','rock','rockDescription'], as_index=False)[['subclass_qid','subClassOfLabel','same_as']].agg(set)
geokb_rocks['subclass_qid'] = geokb_rocks['subclass_qid'].apply(lambda x: [i for i in x])
geokb_rocks['subClassOfLabel'] = geokb_rocks['subClassOfLabel'].apply(lambda x: [i for i in x])
geokb_rocks['same_as'] = geokb_rocks['same_as'].apply(lambda x: [i for i in x])

geokb_rocks['altRockLabel'] = geokb_rocks['rockLabel'].apply(lambda x: x.replace('-',' '))

geokb_rocks_sameas = geokb_rocks[['rock_qid','same_as']].explode('same_as').dropna().reset_index(drop=True)

geokb_rocks.head(10)
# Out:
#   rock_qid                                 rockLabel  \
# 0  Q158195                    composite genesis rock
# 1  Q158196                composite genesis material
# 2  Q158197                          igneous material
# 3  Q158198                      sedimentary material
# 4  Q158199                   unconsolidated material
# 5  Q158200                    anthropogenic material
# 6  Q158201                   phaneritic igneous rock
# 7  Q158202                 fine grained igneous rock
# 8  Q158203  high magnesium fine grained igneous rock
# 9  Q161226     anthropogenic unconsolidated material
#
#                                           rock  \
# 0  https://geokb.wikibase.cloud/entity/Q158195
# 1  https://geokb.wikibase.cloud/entity/Q158196
# 2  https://geokb.wikibase.cloud/entity/Q158197
# 3  https://geokb.wikibase.cloud/entity/Q158198
# 4  https://geokb.wikibase.cloud/entity/Q158199
# 5  https://geokb.wikibase.cloud/entity/Q158200
# 6  https://geokb.wikibase.cloud/entity/Q158201
# 7  https://geokb.wikibase.cloud/entity/Q158202
# 8  https://geokb.wikibase.cloud/entity/Q158203
# 9  https://geokb.wikibase.cloud/entity/Q161226
#
#                                      rockDescription        subclass_qid  \
# 0  Rock formed by geological modification of pre-...            [Q41261]
# 1  Material of unspecified consolidation state fo...   [Q41261, Q158193]
# 2  Earth material formed as a result of igneous p...   [Q41261, Q158193]
# 3  formed by accumulation of solid fragmental mat...   [Q41261, Q158193]
# 4  Compound material composed of an aggregation o...   [Q41261, Q158193]
# 5  Material known to have artificial (human-relat...   [Q41261, Q158193]
# 6  Igneous rock in which the framework of the roc...            [Q41459]
# 7  Igneous rock in which the framework of the roc...            [Q41459]
# 8  fine-grained igneous rock that contains unusua...           [Q158202]
# 9  unconsolidated material known to have artifici...  [Q158200, Q158199]
#
#                                      subClassOfLabel  \
# 0                                    [rock material]
# 1                 [compound material, rock material]
# 2                 [compound material, rock material]
# 3                 [compound material, rock material]
# 4                 [compound material, rock material]
# 5                 [compound material, rock material]
# 6                                     [igneous rock]
# 7                                     [igneous rock]
# 8                        [fine grained igneous rock]
# 9  [anthropogenic material, unconsolidated material]
#
#                                              same_as  \
# 0  [http://resource.geosciml.org/classifier/cgi/l...
# 1  [https://w3id.org/gso/rockmaterial/compositege...
# 2  [https://w3id.org/gso/rockmaterial/igneousmate...
# 3  [https://w3id.org/gso/rockmaterial/sedimentary...
# 4  [https://w3id.org/gso/rockmaterial/unconsolida...
# 5  [https://w3id.org/gso/rockmaterial/anthropogen...
# 6  [https://w3id.org/gso/rockmaterial/phaneritici...
# 7  [http://resource.geosciml.org/classifier/cgi/l...
# 8  [http://resource.geosciml.org/classifier/cgi/l...
# 9  [https://w3id.org/gso/rockmaterial/anthropogen...
#
#                                altRockLabel
# 0                    composite genesis rock
# 1                composite genesis material
# 2                          igneous material
# 3                      sedimentary material
# 4                   unconsolidated material
# 5                    anthropogenic material
# 6                   phaneritic igneous rock
# 7                 fine grained igneous rock
# 8  high magnesium fine grained igneous rock
# 9     anthropogenic unconsolidated material

# %% [markdown]
# # GSO Rock Materials

# %%
gsrm = rdflib.Graph()
gsrm.parse(
    "https://raw.githubusercontent.com/Loop3D/GKM/master/Loop3D-GSO/Modules/GSO-Geologic_Rock_Material.ttl",
    format="ttl"
)

query_rocks = """
    SELECT ?rock ?rock_label ?rock_comment ?subclass_of ?source
    WHERE {
        # ?rock a owl:Class ;
            rdfs:label ?rock_label ;
            rdfs:comment ?rock_comment ;
            rdfs:subClassOf ?subclass_of ;
            dct:source ?source .
        FILTER (STRSTARTS(STR(?rock), STR(gsrm:)))
    }
"""

gsrm_rocks = gsrm.query(query_rocks)

rows = []
for row in gsrm_rocks:
    rows.append({
        'rock': row[0],
        'rock_label': row[1],
        'rock_comment': row[2],
        'subclass_of': row[3],
        'source': row[4]
    })
df_gsrm = pd.DataFrame(rows)

df_gsrm['rockLabel'] = df_gsrm['rock_label'].apply(lambda x: x.value)
df_gsrm['rock_labels_lang'] = df_gsrm['rock_label'].apply(lambda x: x.language)

df_gsrm['rockDescription'] = df_gsrm['rock_comment'].apply(lambda x: x.value)
df_gsrm['reference'] = df_gsrm['source'].apply(lambda x: x.value)

df_gsrm['iri'] = df_gsrm['rock'].str.replace('_', '').str.replace('-', '').str.lower()
df_gsrm['subClassOf'] = df_gsrm['subclass_of'].apply(lambda x: x.replace('_', '').lower())

df_gsrm = df_gsrm[df_gsrm['rock_labels_lang'] == 'en'][['iri','rockLabel','rockDescription','reference','subClassOf']].reset_index(drop=True)
df_gsrm = df_gsrm.convert_dtypes()

df_gsrm = df_gsrm.groupby(['iri','rockLabel'], as_index=False).agg(set).reset_index(drop=True)

df_gsrm.head(10)
# Out:
#                                                  iri  \
# 0  https://w3id.org/gso/rockmaterial/acidicigneou...
# 1  https://w3id.org/gso/rockmaterial/acidicigneou...
# 2  https://w3id.org/gso/rockmaterial/advancedargi...
# 3  https://w3id.org/gso/rockmaterial/albiticalter...
# 4  https://w3id.org/gso/rockmaterial/alkalifeldsp...
# 5  https://w3id.org/gso/rockmaterial/alkalifeldsp...
# 6  https://w3id.org/gso/rockmaterial/alkalifeldsp...
# 7  https://w3id.org/gso/rockmaterial/alkalifeldsp...
# 8  https://w3id.org/gso/rockmaterial/alkalifeldsp...
# 9  https://w3id.org/gso/rockmaterial/alkalifeldsp...
#
#                         rockLabel  \
# 0         acidic igneous material
# 1             acidic igneous rock
# 2  advanced argillic altered rock
# 3            albitic altered rock
# 4         alkali feldspar granite
# 5        alkali feldspar rhyolite
# 6         alkali feldspar syenite
# 7   alkali feldspar syenitic rock
# 8        alkali feldspar trachyte
# 9  alkali feldspar trachytic rock
#
#                                      rockDescription  \
# 0  {Igneous material with more than 63 percent Si...
# 1     {Igneous rock with more than 63 percent SiO2.}
# 2  {Advanced argillic alteration occurs under low...
# 3                               {definition missing}
# 4  {Granitic rock that has a plagioclase to total...
# 5  {Rhyolitoid in which the ratio of plagioclase ...
# 6  {Alkali feldspar syenitic rock that contains 0...
# 7  {Syenitoid with a plagioclase to total feldspa...
# 8  {Trachytoid that has a plagioclase to total fe...
# 9  {Trachytoid that has a plagioclase to total fe...
#
#                                            reference  \
# 0                       {after LeMaitre et al. 2002}
# 1                       {after LeMaitre et al. 2002}
# 2  {Antonio Arribas, Jeffrey Hedenquist, 2019, En...
# 3    {CGI alterationtype SKOS vocabulary 2012-11-24}
# 4                             {LeMaitre et al. 2002}
# 5                             {LeMaitre et al. 2002}
# 6                             {LeMaitre et al. 2002}
# 7                             {LeMaitre et al. 2002}
# 8                             {LeMaitre et al. 2002}
# 9                             {LeMaitre et al. 2002}
#
#                                           subClassOf
# 0  {https://w3id.org/gso/rockmaterial/igneousmate...
# 1  {https://w3id.org/gso/rockmaterial/acidicigneo...
# 2    {https://w3id.org/gso/rockmaterial/alteredrock}
# 3    {https://w3id.org/gso/rockmaterial/alteredrock}
# 4      {https://w3id.org/gso/rockmaterial/granitoid}
# 5     {https://w3id.org/gso/rockmaterial/rhyolitoid}
# 6  {https://w3id.org/gso/rockmaterial/alkalifelds...
# 7      {https://w3id.org/gso/rockmaterial/syenitoid}
# 8  {https://w3id.org/gso/rockmaterial/alkalifelds...
# 9     {https://w3id.org/gso/rockmaterial/trachytoid}

# %% [markdown]
# ## GSRM Transformations

# %%
def split_desc(x):
    first_desc = next(iter(x), None)
    if first_desc is None:
        return None, None
    
    joined_desc = '\n'.join(x)
    
    if len(x) == 1:
        if len(first_desc) <= 250:
            short_desc = first_desc
            long_desc = None
        else:
            first_sentence = first_desc.split('.')[0]
            if len(first_sentence) <= 250:
                short_desc = first_sentence
                long_desc = joined_desc
            else:
                short_desc = first_desc[:250]
                long_desc = joined_desc
    else:
        long_desc = joined_desc
        if len(first_desc) <= 250:
            short_desc = first_desc
        else:
            first_sentence = first_desc.split('.')[0]
            if len(first_sentence) <= 250:
                short_desc = first_sentence
            else:
                short_desc = first_desc[:250]

    if short_desc == 'definition missing':
        short_desc = 'a rock material class from the Geoscience Ontology missing a definition'

    return short_desc, long_desc
        
df_gsrm[['description', 'long_description']] = df_gsrm['rockDescription'].apply(split_desc).apply(pd.Series)

# %%
def reference_items(x):
    items = []
    if 'LeMaitre' in x:
        items.append('Q161230')
    if 'Neuendorf' in x:
        items.append('Q161227')
    if 'SLTT' in x:
        items.append('Q70308')
    if 'consolidationdegree' in x:
        items.append('Q161232')
    if 'alterationtype' in x:
        items.append('Q161231')

    return items

gsrm_references = df_gsrm[['iri','reference']].explode('reference').dropna().reset_index(drop=True)
gsrm_references['reference'] = gsrm_references['reference'].apply(lambda x: [i.strip() for i in x.split(';')])
gsrm_references = gsrm_references.explode('reference').reset_index(drop=True)

gsrm_references['reference_items'] = gsrm_references['reference'].apply(reference_items)
gsrm_references['reference_urls'] = gsrm_references['reference'].apply(lambda x: re.findall(r'https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+[/\w.-]*', x))
gsrm_references['reference_string'] = gsrm_references.apply(lambda x: None if x['reference'].lower() == 'this vocabulary' or x['reference_items'] or x['reference_urls'] else x['reference'], axis=1)

# %% [markdown]
# # Initial Pass
# In this initial pass, I'll make a few modifications to items that align between what we already have in the GeoKB and the GSO-GSRM simply on labels.
# * Add same as claim pointing to corrected IRI for GSO entity
# * Change label to the GSO variation (without hyphens), adding the Mindat variation as an alias
# * Change descriptions to GSO variation
# * Add the Mindat description and longer GSO-GSRM description (where applicable) to the item discussion page

# %%
gsrm_in_geokb = pd.merge(
    left=df_gsrm[['iri','rockLabel','description','long_description']],
    right=geokb_rocks[['rock_qid','altRockLabel','rockLabel','same_as','rockDescription']].rename(columns={'rockLabel':'current_label'}),
    how='left',
    left_on='rockLabel',
    right_on='altRockLabel'
)

gsrm_in_geokb[
    gsrm_in_geokb['rock_qid'].notna()
    &
    ~gsrm_in_geokb['iri'].isin(geokb_rocks_sameas['same_as'])
].head()
# Out:
# Empty DataFrame
# Columns: [iri, rockLabel, description, long_description, rock_qid, altRockLabel, current_label, same_as, rockDescription]
# Index: []

# %%
for _, row in gsrm_in_geokb[
    gsrm_in_geokb['rock_qid'].notna()
    &
    ~gsrm_in_geokb['iri'].isin(geokb_rocks_sameas['same_as'])
    &
    ~gsrm_in_geokb['rock_qid'].isin(processed_qids)
].iterrows():
    item = geokb.wbi.item.get(row['rock_qid'])
    if row['rockLabel'] != row['current_label']:
        item.labels.set('en', row['rockLabel'])
        item.aliases.set('en', row['current_label'], action_if_exists=geokb.action_if_exists.APPEND_OR_REPLACE)

    item.descriptions.set('en', row['description'])

    same_as_claims = [
        geokb.datatypes.URL(
            prop_nr=geokb.prop_lookup['same as'],
            value=row['iri']
        )
    ]

    for url in row['same_as']:
        same_as_claims.append(
            geokb.datatypes.URL(
                prop_nr=geokb.prop_lookup['same as'],
                value=url
            )
        )
    
    item.claims.add(
        same_as_claims,
        action_if_exists=geokb.action_if_exists.REPLACE_ALL
    )

    try:
        response = item.write(
            summary='Updated rock class item with Geoscience Ontology GSRM data'
        )
        print("UPDATED ITEM:", response.id)

        descriptive_texts = f"= Mindat Description =\n{row['rockDescription']}"

        if isinstance(row['long_description'], str):
            descriptive_texts = f"{descriptive_texts}\n= Geoscience Ontology Description =\n{row['long_description']}"

        item_page = geokb.mw_site.pages[f'Item_talk:{row["rock_qid"]}']
        item_page.save(descriptive_texts, summary='Updated rock class item discussion page with longer source data descriptions')
        print("UPDATED ITEM TALK PAGE:", row['rock_qid'])
    except Exception as e:
        print(row['rock_qid'], str(e))

# %% [markdown]
# # Missing GSO-GSRM Items

# %%
df_gsrm[~df_gsrm['iri'].isin(geokb_rocks_sameas['same_as'])].head()
# Out:
#                                                  iri  \
# 0  https://w3id.org/gso/rockmaterial/acidicigneou...
# 1  https://w3id.org/gso/rockmaterial/acidicigneou...
# 2  https://w3id.org/gso/rockmaterial/advancedargi...
# 3  https://w3id.org/gso/rockmaterial/albiticalter...
# 7  https://w3id.org/gso/rockmaterial/alkalifeldsp...
#
#                         rockLabel  \
# 0         acidic igneous material
# 1             acidic igneous rock
# 2  advanced argillic altered rock
# 3            albitic altered rock
# 7   alkali feldspar syenitic rock
#
#                                      rockDescription  \
# 0  {Igneous material with more than 63 percent Si...
# 1     {Igneous rock with more than 63 percent SiO2.}
# 2  {Advanced argillic alteration occurs under low...
# 3                               {definition missing}
# 7  {Syenitoid with a plagioclase to total feldspa...
#
#                                            reference  \
# 0                       {after LeMaitre et al. 2002}
# 1                       {after LeMaitre et al. 2002}
# 2  {Antonio Arribas, Jeffrey Hedenquist, 2019, En...
# 3    {CGI alterationtype SKOS vocabulary 2012-11-24}
# 7                             {LeMaitre et al. 2002}
#
#                                           subClassOf  \
# 0  {https://w3id.org/gso/rockmaterial/igneousmate...
# 1  {https://w3id.org/gso/rockmaterial/acidicigneo...
# 2    {https://w3id.org/gso/rockmaterial/alteredrock}
# 3    {https://w3id.org/gso/rockmaterial/alteredrock}
# 7      {https://w3id.org/gso/rockmaterial/syenitoid}
#
#                                          description  \
# 0   Igneous material with more than 63 percent SiO2.
# 1       Igneous rock with more than 63 percent SiO2.
# 2  Advanced argillic alteration occurs under lowe...
# 3  a rock material class from the Geoscience Onto...
# 7  Syenitoid with a plagioclase to total feldspar...
#
#                                     long_description
# 0                                               None
# 1                                               None
# 2  Advanced argillic alteration occurs under lowe...
# 3                                               None
# 7                                               None

# %%
new_items = []
exceptions = []

for _, row in df_gsrm[~df_gsrm['iri'].isin(geokb_rocks_sameas['same_as'])].iterrows():
    item = geokb.wbi.item.new()
    item.labels.set('en', row['rockLabel'])
    item.descriptions.set('en', row['description'])

    item.claims.add(
        geokb.datatypes.URL(
            prop_nr=geokb.prop_lookup['same as'],
            value=row['iri']
        )
    )

    try:
        response = item.write(
            summary="Added new rock class item from Geoscience Ontology GSRM data"
        )
        print("CREATED ITEM:", response.id)
        if isinstance(row['long_description'], str):
            item_page = geokb.mw_site.pages[f'Item_talk:{response.id}']
            item_page.save(f"= Geoscience Ontology Description =\n{row['long_description']}", summary='Added rock class item discussion page with source data description')
            print("CREATED ITEM TALK PAGE:", response.id)
        new_items.append({
            'iri': row['iri'],
            'qid': response.id
        })
    except Exception as e:
        print("EXCEPTION:", row['rockLabel'], str(e))
        exceptions.append({
            'iri': row['iri'],
            'exception': str(e)
        })
# Out:
# CREATED ITEM: Q161233
# CREATED ITEM: Q161234
# CREATED ITEM: Q161235
# CREATED ITEM TALK PAGE: Q161235
# CREATED ITEM: Q161236
# CREATED ITEM: Q161237
# CREATED ITEM: Q161238
# CREATED ITEM: Q161239
# CREATED ITEM: Q161240
# CREATED ITEM TALK PAGE: Q161240
# CREATED ITEM: Q161241
# CREATED ITEM: Q161242
# CREATED ITEM TALK PAGE: Q161242
# CREATED ITEM: Q161243
# CREATED ITEM TALK PAGE: Q161243
# CREATED ITEM: Q161244
# CREATED ITEM: Q161245
# CREATED ITEM: Q161246
# CREATED ITEM: Q161247
# CREATED ITEM: Q161248
# CREATED ITEM: Q161249
# CREATED ITEM TALK PAGE: Q161249
# CREATED ITEM: Q161250
# CREATED ITEM TALK PAGE: Q161250
# CREATED ITEM: Q161251
# CREATED ITEM: Q161252
# CREATED ITEM: Q161253
# CREATED ITEM: Q161254
# CREATED ITEM: Q161255
# CREATED ITEM: Q161256
# CREATED ITEM: Q161257
# CREATED ITEM: Q161258
# CREATED ITEM: Q161259
# CREATED ITEM TALK PAGE: Q161259
# CREATED ITEM: Q161260
# CREATED ITEM: Q161261
# CREATED ITEM: Q161262
# CREATED ITEM TALK PAGE: Q161262
# CREATED ITEM: Q161263
# CREATED ITEM TALK PAGE: Q161263
# CREATED ITEM: Q161264
# CREATED ITEM TALK PAGE: Q161264
# CREATED ITEM: Q161265
# CREATED ITEM TALK PAGE: Q161265
# CREATED ITEM: Q161266
# CREATED ITEM TALK PAGE: Q161266
# CREATED ITEM: Q161267
# CREATED ITEM: Q161268
# CREATED ITEM TALK PAGE: Q161268
# CREATED ITEM: Q161269
# CREATED ITEM: Q161270
# CREATED ITEM TALK PAGE: Q161270
# CREATED ITEM: Q161271
# CREATED ITEM: Q161272
# CREATED ITEM: Q161273
# CREATED ITEM: Q161274
# CREATED ITEM: Q161275
# CREATED ITEM: Q161276
# CREATED ITEM TALK PAGE: Q161276
# CREATED ITEM: Q161277
# CREATED ITEM: Q161278
# CREATED ITEM: Q161279
# CREATED ITEM: Q161280
# CREATED ITEM: Q161281
# CREATED ITEM: Q161282
# CREATED ITEM: Q161283
# CREATED ITEM TALK PAGE: Q161283
# CREATED ITEM: Q161284
# CREATED ITEM TALK PAGE: Q161284
# CREATED ITEM: Q161285
# CREATED ITEM: Q161286
# CREATED ITEM: Q161287
# CREATED ITEM TALK PAGE: Q161287
# CREATED ITEM: Q161288
# CREATED ITEM TALK PAGE: Q161288
# CREATED ITEM: Q161289
# CREATED ITEM TALK PAGE: Q161289
# CREATED ITEM: Q161290
# CREATED ITEM TALK PAGE: Q161290
# CREATED ITEM: Q161291
# CREATED ITEM: Q161292
# CREATED ITEM: Q161293
# CREATED ITEM TALK PAGE: Q161293
# CREATED ITEM: Q161294
# CREATED ITEM: Q161295
# CREATED ITEM: Q161296
# CREATED ITEM: Q161297
# CREATED ITEM: Q161298
# CREATED ITEM: Q161299
# CREATED ITEM: Q161300
# CREATED ITEM: Q161301
# CREATED ITEM: Q161302
# CREATED ITEM TALK PAGE: Q161302
# CREATED ITEM: Q161303
# CREATED ITEM: Q161304
# CREATED ITEM: Q161305
# CREATED ITEM: Q161306
# CREATED ITEM: Q161307
# CREATED ITEM: Q161308
# CREATED ITEM: Q161309
# CREATED ITEM TALK PAGE: Q161309
# CREATED ITEM: Q161310
# CREATED ITEM TALK PAGE: Q161310
# CREATED ITEM: Q161311
# CREATED ITEM TALK PAGE: Q161311
# CREATED ITEM: Q161312
# CREATED ITEM: Q161313
# CREATED ITEM: Q161314
# CREATED ITEM: Q161315
# CREATED ITEM: Q161316
# CREATED ITEM: Q161317
# CREATED ITEM: Q161318
# CREATED ITEM: Q161319
# CREATED ITEM TALK PAGE: Q161319
# CREATED ITEM: Q161320
# CREATED ITEM: Q161321
# CREATED ITEM: Q161322
# CREATED ITEM TALK PAGE: Q161322
# CREATED ITEM: Q161323
# CREATED ITEM: Q161324
# CREATED ITEM: Q161325
# CREATED ITEM TALK PAGE: Q161325
# CREATED ITEM: Q161326
# CREATED ITEM TALK PAGE: Q161326
# CREATED ITEM: Q161327
# CREATED ITEM: Q161328
# CREATED ITEM: Q161329
# CREATED ITEM: Q161330
# CREATED ITEM TALK PAGE: Q161330
# CREATED ITEM: Q161331
# CREATED ITEM: Q161332
# CREATED ITEM: Q161333
# CREATED ITEM: Q161334
# CREATED ITEM: Q161335
# CREATED ITEM TALK PAGE: Q161335
# CREATED ITEM: Q161336
# CREATED ITEM: Q161337
# CREATED ITEM: Q161338
# CREATED ITEM: Q161339
# CREATED ITEM TALK PAGE: Q161339
# CREATED ITEM: Q161340
# CREATED ITEM: Q161341
# CREATED ITEM: Q161342
# CREATED ITEM: Q161343
# CREATED ITEM: Q161344
# CREATED ITEM: Q161345
# CREATED ITEM TALK PAGE: Q161345
# CREATED ITEM: Q161346
# CREATED ITEM: Q161347
# CREATED ITEM TALK PAGE: Q161347
# CREATED ITEM: Q161348
# CREATED ITEM: Q161349
# CREATED ITEM: Q161350
# CREATED ITEM: Q161351
# CREATED ITEM TALK PAGE: Q161351
# CREATED ITEM: Q161352
# CREATED ITEM: Q161353
# CREATED ITEM: Q161354
# CREATED ITEM: Q161355
# CREATED ITEM: Q161356
# CREATED ITEM: Q161357
# CREATED ITEM: Q161358
# CREATED ITEM: Q161359
# CREATED ITEM TALK PAGE: Q161359
# CREATED ITEM: Q161360
# CREATED ITEM TALK PAGE: Q161360
# CREATED ITEM: Q161361
# CREATED ITEM: Q161362
# CREATED ITEM: Q161363
# CREATED ITEM: Q161364
# CREATED ITEM: Q161365
# CREATED ITEM: Q161366
# CREATED ITEM: Q161367
# CREATED ITEM: Q161368
# CREATED ITEM: Q161369
# CREATED ITEM: Q161370

# %% [markdown]
# # Classification and References

# %%
extra_items = [
    {
        'iri': 'https://w3id.org/gso/geology/rockmaterial',
        'qid': 'Q41261'
    },
    {
        'iri': 'https://w3id.org/gso/rockmaterial/alteredrock',
        'qid': 'Q161371'
    }
]

gsrm_geokb_mapping = pd.concat([
    geokb_rocks_sameas[geokb_rocks_sameas['same_as'].str.contains('w3id.org')].rename(columns={'same_as':'iri', 'rock_qid':'qid'}),
    pd.DataFrame(new_items),
    pd.DataFrame(extra_items)
])

# %%
gsrm_subclasses = pd.merge(
    left=df_gsrm[['iri','subClassOf']],
    right=gsrm_geokb_mapping,
    how='left',
    on='iri'
)

gsrm_subclasses = pd.merge(
    left=gsrm_subclasses.explode('subClassOf'),
    right=gsrm_geokb_mapping.rename(columns={'qid': 'subClassOf_qid', 'iri': 'subClassOf'}),
    how='left',
    on='subClassOf'
)

# %%
for _, row in gsrm_subclasses[gsrm_subclasses['subClassOf_qid'].notna()].groupby(['qid','iri'], as_index=False)['subClassOf_qid'].agg(list).iterrows():
    subclass_ref_source = gsrm_references[gsrm_references['iri'] == row['iri']]
    subclass_refs = []
    # Add reference for the GSO item
    subclass_refs.append(
        geokb.datatypes.Item(
            prop_nr=geokb.prop_lookup['knowledge source'],
            value='Q161225'
        )
    )
    # Add record specific references from the ontology
    for i, r in subclass_ref_source.iterrows():
        for item_qid in r['reference_items']:
            subclass_refs.append(
                geokb.datatypes.Item(
                    prop_nr=geokb.prop_lookup['knowledge source'],
                    value=item_qid
                )
            )
        for url in r['reference_urls']:
            subclass_refs.append(
                geokb.datatypes.URL(
                    prop_nr=geokb.prop_lookup['reference URL'],
                    value=url
                )
            )
        if isinstance(r['reference_string'], str):
            subclass_refs.append(
                geokb.datatypes.String(
                    prop_nr=geokb.prop_lookup['reference statement'],
                    value=r['reference_string']
                )
            )
    
    item = geokb.wbi.item.get(row['qid'])

    # subclass_claims = item.claims.get('P2')

    new_claims = []
    for parent_qid in row['subClassOf_qid']:
        new_claims.append(
            geokb.datatypes.Item(
                prop_nr=geokb.prop_lookup['subclass of'],
                value=parent_qid,
                references=subclass_refs
            )
        )

    item.claims.add(new_claims, action_if_exists=geokb.action_if_exists.APPEND_OR_REPLACE)

    # display(item.get_json())

    try:
        response = item.write(
            summary='Updated rock class item with Geoscience Ontology GSRM subclass data'
        )
        print(response.id)
    except Exception as e:
        print(row['qid'], str(e))
# Out:
# Q158195
# Q158196
# Q158197
# Q158198
# Q158199
# Q158200
# Q158201
# Q158202
# Q158203
# Q161226
# Q161228
# Q161229
# Q161233
# Q161234
# Q161235
# Q161236
# Q161237
# Q161238
# Q161239
# Q161240
# Q161242
# Q161243
# Q161244
# Q161245
# Q161246
# Q161247
# Q161248
# Q161249
# Q161250
# Q161251
# Q161252
# Q161253
# Q161254
# Q161255
# Q161256
# Q161257
# Q161258
# Q161259
# Q161260
# Q161261
# Q161262
# Q161263
# Q161264
# Q161265
# Q161266
# Q161267
# Q161268
# Q161269
# Q161270
# Q161271
# Q161274
# Q161275
# Q161276
# Q161277
# Q161278
# Q161279
# Q161280
# Q161281
# Q161282
# Q161283
# Q161284
# Q161285
# Q161286
# Q161287
# Q161288
# Q161289
# Q161290
# Q161291
# Q161292
# Q161293
# Q161294
# Q161295
# Q161296
# Q161297
# Q161298
# Q161299
# Q161300
# Q161301
# Q161302
# Q161303
# Q161304
# Q161305
# Q161306
# Q161307
# Q161308
# Q161309
# Q161310
# Q161311
# Q161312
# Q161313
# Q161314
# Q161315
# Q161316
# Q161317
# Q161318
# Q161319
# Q161320
# Q161321
# Q161322
# Q161323
# Q161324
# Q161325
# Q161326
# Q161327
# Q161328
# Q161329
# Q161330
# Q161331
# Q161332
# Q161333
# Q161334
# Q161335
# Q161336
# Q161337
# Q161338
# Q161339
# Q161340
# Q161341
# Q161342
# Q161343
# Q161344
# Q161345
# Q161346
# Q161347
# Q161348
# Q161349
# Q161350
# Q161351
# Q161352
# Q161353
# Q161354
# Q161355
# Q161356
# Q161357
# Q161358
# Q161359
# Q161360
# Q161361
# Q161362
# Q161364
# Q161365
# Q161366
# Q161367
# Q161368
# Q161369
# Q161370
# Q41276
# Q41283
# Q41285
# Q41286
# Q41289
# Q41290
# Q41298
# Q41308
# Q41309
# Q41317
# Q41318
# Q41362
# Q41366
# Q41370
# Q41372
# Q41375
# Q41377
# Q41381
# Q41404
# Q41438
# Q41439
# Q41459
# Q41460
# Q41461
# Q41533
# Q41537
# Q41543
# Q41555
# Q41558
# Q41564
# Q41568
# Q41569
# Q41572
# Q41576
# Q41580
# Q41584
# Q41591
# Q41594
# Q41597
# Q41599
# Q41608
# Q41609
# Q41618
# Q41622
# Q41626
# Q41630
# Q41633
# Q41640
# Q41641
# Q41645
# Q41649
# Q41674
# Q41679
# Q41682
# Q41690
# Q41691
# Q41694
# Q41701
# Q41709
# Q41717
# Q41721
# Q41727
# Q41733
# Q41738
# Q41750
# Q41752
# Q41757
# Q41765
# Q41776
# Q41778
# Q41779
# Q41791
# Q41793
# Q41794
# Q41798
# Q41804
# Q41805
# Q41806
# Q41807
# Q41808
# Q41811
# Q41812
# Q41816
# Q41820
# Q41825
# Q41826
# Q41830
# Q41838
# Q41840
# Q41851
# Q41854
# Q41856
# Q41860
# Q41872
# Q41873
# Q41874
# Q41884
# Q41924
# Q41925
# Q41926
# Q41930
# Q41932
# Q41935
# Q41937
# Q41942
# Q41946
# Q41948
# Q41949
# Q41959
# Q42045
# Q42090
# Q42092
# Q421
# Q42307
# Q42333
# Q42362
# Q42387
# Q42507
# Q42508
# Q42511
# Q42538
# Q42575
# Q42581
# Q42582
# Q42583
# Q42584
# Q42585
# Q42586
# Q42587
# Q42589
# Q42591
# Q42592
# Q42594
# Q42596
# Q42597
# Q43004
# Q43022
# Q43036
# Q43037
# Q43142
# Q43155
# Q43221
# Q43254
# Q43274
# Q43277
# Q43299
# Q43306
# Q43307
# Q43329
# Q43340
# Q43347
# Q43355
# Q43488
# Q43655
# Q43659
# Q43660
# Q43663
# Q43670
# Q43671
# Q43905
