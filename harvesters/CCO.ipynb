# %% [markdown]
# This notebook works through those aspects of the Common Core Ontologies that we are leveraging within the GeoKB for cases where a more specific domain ontology such as the Geoscience Ontology uses the CCO as a basis for knowledge organization.
#
# Note: There is still more work to do on this, but I'm committing for now to move on to other work.

# %%
import rdflib
import pandas as pd
from wbmaker import WikibaseConnection
import requests

# %%
geokb = WikibaseConnection('GEOKB_CLOUD')

# %% [markdown]
# # CCO same as links

# %%
q_geokb_cco = """
PREFIX wdt: <https://geokb.wikibase.cloud/prop/direct/>

SELECT ?item ?itemLabel ?same_as
WHERE {
    # ?item wdt:P84 ?same_as .
    FILTER CONTAINS(STR(?same_as), "CommonCoreOntologies")
    SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""

geokb_cco = geokb.sparql_query(q_geokb_cco)
geokb_cco
# Out:
#                                            item                     itemLabel  \
# 0        https://geokb.wikibase.cloud/entity/Q4                  organization
# 1      https://geokb.wikibase.cloud/entity/P108            is affiliated with
# 2      https://geokb.wikibase.cloud/entity/P171                 has affiliate
# 3   https://geokb.wikibase.cloud/entity/Q163020               group of agents
# 4        https://geokb.wikibase.cloud/entity/Q8                        report
# 5        https://geokb.wikibase.cloud/entity/Q5                      document
# 6   https://geokb.wikibase.cloud/entity/Q163033  information bearing artifact
# 7   https://geokb.wikibase.cloud/entity/Q163034             material artifact
# 8      https://geokb.wikibase.cloud/entity/P187                 capability of
# 9      https://geokb.wikibase.cloud/entity/P188                has capability
# 10     https://geokb.wikibase.cloud/entity/P189                has subsidiary
# 11     https://geokb.wikibase.cloud/entity/P190              is subsidiary of
# 12     https://geokb.wikibase.cloud/entity/P191                    supervises
# 13     https://geokb.wikibase.cloud/entity/P192              is supervised by
# 14  https://geokb.wikibase.cloud/entity/Q163039                         agent
# 15       https://geokb.wikibase.cloud/entity/Q3                        person
# 16  https://geokb.wikibase.cloud/entity/Q159054                        animal
# 17  https://geokb.wikibase.cloud/entity/Q159257                      organism
# 18     https://geokb.wikibase.cloud/entity/P194       capability of aggregate
# 19     https://geokb.wikibase.cloud/entity/P195      aggregate has capability
# 20  https://geokb.wikibase.cloud/entity/Q163041              agent capability
#
#                                               same_as
# 0   https://www.ontologyrepository.com/CommonCoreO...
# 1   https://www.ontologyrepository.com/CommonCoreO...
# 2   http://www.ontologyrepository.com/CommonCoreOn...
# 3   http://www.ontologyrepository.com/CommonCoreOn...
# 4   http://www.ontologyrepository.com/CommonCoreOn...
# 5   http://www.ontologyrepository.com/CommonCoreOn...
# 6   http://www.ontologyrepository.com/CommonCoreOn...
# 7   http://www.ontologyrepository.com/CommonCoreOn...
# 8   http://www.ontologyrepository.com/CommonCoreOn...
# 9   http://www.ontologyrepository.com/CommonCoreOn...
# 10  http://www.ontologyrepository.com/CommonCoreOn...
# 11  http://www.ontologyrepository.com/CommonCoreOn...
# 12  http://www.ontologyrepository.com/CommonCoreOn...
# 13  http://www.ontologyrepository.com/CommonCoreOn...
# 14  http://www.ontologyrepository.com/CommonCoreOn...
# 15  https://www.ontologyrepository.com/CommonCoreO...
# 16  https://www.ontologyrepository.com/CommonCoreO...
# 17  https://www.ontologyrepository.com/CommonCoreO...
# 18  http://www.ontologyrepository.com/CommonCoreOn...
# 19  http://www.ontologyrepository.com/CommonCoreOn...
# 20  http://www.ontologyrepository.com/CommonCoreOn...

# %%
raw_github_path = "https://raw.githubusercontent.com/CommonCoreOntology/CommonCoreOntologies/master/"

cco_contents_url = "https://api.github.com/repos/CommonCoreOntology/CommonCoreOntologies/contents/"
cco_contents = requests.get(cco_contents_url).json()
[i['name'] for i in cco_contents if i['name'].endswith('.ttl')]
# Out:
# ['AgentOntology.ttl',
#  'AllCoreOntology.ttl',
#  'ArtifactOntology.ttl',
#  'CurrencyUnitOntology.ttl',
#  'EventOntology.ttl',
#  'ExtendedRelationOntology.ttl',
#  'FacilityOntology.ttl',
#  'GeospatialOntology.ttl',
#  'InformationEntityOntology.ttl',
#  'ModalRelationOntology.ttl',
#  'ObsoleteTerms.ttl',
#  'QualityOntology.ttl',
#  'TimeOntology.ttl',
#  'UnitsOfMeasureOntology.ttl']

# %%
q_types = """
SELECT DISTINCT ?type ?label
WHERE {
    # ?item rdf:type ?type .
    OPTIONAL {
        # ?type rdfs:label ?label .
    }
}
"""

q_classes = """
SELECT ?item ?label ?definition ?superclass ?superclassLabel
WHERE {
    # ?item rdf:type owl:Class ;
          rdfs:label ?label ;
          cco:definition ?definition ;
          rdfs:subClassOf ?superclass .
    OPTIONAL {
        # ?superclass rdfs:label ?superclassLabel .
    }
}
"""

q_properties = """
SELECT ?item ?label ?definition ?superprop ?superpropLabel
WHERE {
    # ?item rdf:type owl:ObjectProperty ;
          rdfs:label ?label ;
          cco:definition ?definition ;
          rdfs:subPropertyOf ?superprop .
    OPTIONAL {
        # ?superprop rdfs:label ?superpropLabel .
    }
    
}
"""

q_class_hierarchy = """
SELECT ?item ?label ?definition ?superclass ?superclassLabel
WHERE {
    # ?item rdf:type owl:Class ;
          rdfs:label ?label ;
          cco:definition ?definition ;
          rdfs:subClassOf ?superclass .
    OPTIONAL {
        # ?superclass rdfs:label ?superclassLabel .
    }
}
"""

# %%
cco_agent = rdflib.Graph()
cco_agent.parse(raw_github_path + "AgentOntology.ttl", format="ttl")

# geokb.df_from_graph(cco_agent.query(q_classes)).to_csv('../data/cco_agent_classes.csv', index=False)
# geokb.df_from_graph(cco_agent.query(q_properties)).to_csv('../data/cco_agent_properties.csv', index=False)
# Out:
# <Graph identifier=Nf7f6dc0d710546b6acb6d059536efa66 (<class 'rdflib.graph.Graph'>)>

# %%
cco = rdflib.ConjunctiveGraph()
cco.parse("https://raw.githubusercontent.com/CommonCoreOntology/CommonCoreOntologies/master/AllCoreOntology.ttl", format="ttl")
# Out:
# <Graph identifier=N7c29ad33c0f7482fab67331fcf425657 (<class 'rdflib.graph.Graph'>)>

# %%
q = """
SELECT *
WHERE {
    # ?s ?p ?o .
}
"""

cco = geokb.df_from_graph(cco.query(q))

# %%
cco_classes = geokb.df_from_graph(cco_agent.query(q_classes))
cco_classes.head()
# Out:
#                                                 item               label  \
# 0  http://www.ontologyrepository.com/CommonCoreOn...   Action Permission
# 1  http://www.ontologyrepository.com/CommonCoreOn...  Action Prohibition
# 2  http://www.ontologyrepository.com/CommonCoreOn...   Action Regulation
# 3  http://www.ontologyrepository.com/CommonCoreOn...  Action Requirement
# 4  http://www.ontologyrepository.com/CommonCoreOn...          Affordance
#
#                                           definition  \
# 0        An Action Regulation that permits some Act.
# 1      An Action Regulation that prohibits some Act.
# 2  A Directive Information Content Entity that pr...
# 3       An Action Regulation that requires some Act.
# 4  A Realizable Entity of an Independent Continua...
#
#                                           superclass    superclassLabel
# 0  http://www.ontologyrepository.com/CommonCoreOn...  Action Regulation
# 1  http://www.ontologyrepository.com/CommonCoreOn...  Action Regulation
# 2  http://www.ontologyrepository.com/CommonCoreOn...               None
# 3  http://www.ontologyrepository.com/CommonCoreOn...  Action Regulation
# 4         http://purl.obolibrary.org/obo/BFO_0000017               None

# %%
geokb.df_from_graph(cco_agent.query(q_properties)).to_dict('records')
# Out:
# [{'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/agent_in',
#   'label': 'agent in',
#   'definition': 'x agent_in y iff y is an instance of Process and x is an instance of Agent, such that x is causally active in y.',
#   'superprop': 'http://purl.obolibrary.org/obo/RO_0000056',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/aggregate_has_capability',
#   'label': 'aggregate has capability',
#   'definition': 'x aggregate_has_capability y iff x is an instance of Object Aggregate and y is an instance of Agent Capability, such that x is aggregate bearer of y.',
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/aggregate_bearer_of',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/capability_of',
#   'label': 'capability of',
#   'definition': 'x capability_of y iff y is an instance of Agent and x is an instance of Agent Capability, such that x inheres in y.',
#   'superprop': 'http://purl.obolibrary.org/obo/RO_0000052',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/capability_of_aggregate',
#   'label': 'capability of aggregate',
#   'definition': 'x capability_of_aggregate y iff y is an instance of Object Aggregate and x is an instance of Agent Capability, such that x inheres in aggregate y.',
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/inheres_in_aggregate',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/has_agent',
#   'label': 'has agent',
#   'definition': 'x has_agent y iff x is an instance of Process and y is an instance of Agent, such that y is causally active in x.',
#   'superprop': 'http://purl.obolibrary.org/obo/RO_0000057',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/has_capability',
#   'label': 'has capability',
#   'definition': 'x has_capability y iff x is an instance of Agent and y is an instance of Agent Capability, such that x bearer of y.',
#   'superprop': 'http://purl.obolibrary.org/obo/RO_0000053',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/has_recipient',
#   'label': 'has recipient',
#   'definition': 'x has_recipient y iff y is an instance of Agent and x is an instance of Act Of Communication, such that y is the recipient and decoder of the InformationContentEntity intended for communication in x.',
#   'superprop': 'http://purl.obolibrary.org/obo/RO_0000057',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/has_sender',
#   'label': 'has sender',
#   'definition': 'y has_sender x iff x is an instance of Agent and y is an instance of Act Of Communication, such that x is the initiator and encoder of the InformationContentEntity intended for communication in y.',
#   'superprop': 'http://purl.obolibrary.org/obo/RO_0000057',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/has_subsidiary',
#   'label': 'has subsidiary',
#   'definition': "An Organization o1 has_subsidiary Organization o2 iff o1 controls o2 by having the capacity to determine the outcome of decisions about o2's financial and operating policies.",
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/has_affiliate',
#   'superpropLabel': 'has affiliate'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/is_maternal_first_cousin_of',
#   'label': 'is maternal first cousin of',
#   'definition': 'Person A is maternal first cousin of Person B iff Person B has mother M and M has sibling P and P is parent of Person A.',
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/is_first_cousin_of',
#   'superpropLabel': 'is first cousin of'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/is_paternal_first_cousin_of',
#   'label': 'is paternal first cousin of',
#   'definition': 'Person A is paternal first cousin of Person B iff Person B has father F and F has sibling P and P is parent of Person A.',
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/is_first_cousin_of',
#   'superpropLabel': 'is first cousin of'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/is_permitted_by',
#   'label': 'is permitted by',
#   'definition': 'y is_permitted_by x at t iff: x is an instance of Action Regulation at time t, and y is an instance of Act at time t, and x prescribes that some agent may be agent in y.',
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/prescribed_by',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/is_prohibited_by',
#   'label': 'is prohibited by',
#   'definition': 'y is_prohibited_by y at t iff: x is an instance of Action Regulation at time t, and y is an instance of Act at time t, and x prescribes that some agent must not be agent in y.',
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/prescribed_by',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/is_required_by',
#   'label': 'is required by',
#   'definition': 'y is_required_by x at t iff: x is an instance of Action Regulation at time t, and y is an instance of Act at time t, and x prescribes that some agent must be agent in y.',
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/prescribed_by',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/is_subsidiary_of',
#   'label': 'is subsidiary of',
#   'definition': "An Organization o2 is_subsidiary_of Organization o1 iff o1 controls o2 by having the capacity to determine the outcome of decisions about o2's financial and operating policies. ",
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/is_affiliated_with',
#   'superpropLabel': 'is affiliated with'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/is_supervised_by',
#   'label': 'is supervised by',
#   'definition': 'A person p1 is supervised by a person p2 by virtue of p1 being directed, managed, or overseen by p2.',
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/is_affiliated_with',
#   'superpropLabel': 'is affiliated with'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/permits',
#   'label': 'permits',
#   'definition': 'x permits y at t iff: x is an instance of Action Regulation at time t, and y is an instance of Act at time t, and x prescribes that some agent may be agent in y.',
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/prescribes',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/prohibits',
#   'label': 'prohibits',
#   'definition': 'x prohibits y at t iff: x is an instance of Action Regulation at time t, and y is an instance of Act at time t, and x prescribes that some agent must not be agent in y.',
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/prescribes',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/receives',
#   'label': 'receives',
#   'definition': 'x receives y iff x is an instance of Agent and y is an instance of Act Of Communication, such that x is the recipient and decoder of the InformationContentEntity intended for communication in y.',
#   'superprop': 'http://purl.obolibrary.org/obo/RO_0000056',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/requires',
#   'label': 'requires',
#   'definition': 'x requires y at t iff: x is an instance of Action Regulation at time t, and y is an instance of Act at time t, and x prescribes that some agent must be agent in y.',
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/prescribes',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/sends',
#   'label': 'sends',
#   'definition': 'x sends y iff x is an instance of Agent and y is an instance of Act Of Communication, such that x is the initiator and encoder of the InformationContentEntity intended for communication in y.',
#   'superprop': 'http://purl.obolibrary.org/obo/RO_0000056',
#   'superpropLabel': 'None'},
#  {'item': 'http://www.ontologyrepository.com/CommonCoreOntologies/supervises',
#   'label': 'supervises',
#   'definition': 'A person p1 supervises a person p2 by virtue of p1 directing, managing, or overseeing p2.',
#   'superprop': 'http://www.ontologyrepository.com/CommonCoreOntologies/has_affiliate',
#   'superpropLabel': 'has affiliate'}]
