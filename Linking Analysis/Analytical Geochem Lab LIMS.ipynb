# %% [markdown]
# This notebook starts to work through the different codelists needed by the upgraded LIMS and its new sample management module replacing an older custom application (WBSSS). It looks at the different data tables used to store pick list values from the legacy system and explores how we can organize some or all of these as concepts within the GeoKB. It does require specialized access to some internal tables and is intended for operation by specific USGS personnel involved in the work.

# %%
import pandas as pd
import requests
import sys
import pyodbc
import rdflib

sys.path.append('../harvesters')

from wbmaker import WikibaseConnection

geokb = WikibaseConnection('GEOKB_CLOUD')

# %%
geokb_rocks_query = """
PREFIX wd: <https://geokb.wikibase.cloud/entity/>
PREFIX wdt: <https://geokb.wikibase.cloud/prop/direct/>

SELECT ?rock ?rockLabel ?rock_alt_label ?rockDescription ?subClassOf ?subClassOfLabel ?same_as
WHERE {
  # ?rock wdt:P2* wd:Q41261 ;
        wdt:P2 ?subClassOf ;
        wdt:P84 ?same_as .
  OPTIONAL {
    # ?rock skos:altLabel ?rock_alt_label .
    FILTER (lang(?rock_alt_label)='en')
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
"""

geokb_rocks = geokb.sparql_query(geokb_rocks_query)

# %%
import pandas_access as mdb

for tbl in mdb.list_tables("../data/WBSSS_Lookup_Tables.accdb"):
    print(tbl)
# Out:
# SSF_LU_ALTERATION
# SSF_LU_ANALYSIS
# SSF_LU_ANALYSIS_BACKUP
# SSF_LU_ASH
# SSF_LU_ASHED
# SSF_LU_BLEND
# SSF_LU_BLENDED
# SSF_LU_CLASSES
# SSF_LU_COMPLETED_TREATMENT
# SSF_LU_CONCENTRATED
# SSF_LU_DATE_FORMAT
# SSF_LU_DATUM
# SSF_LU_DEPOSIT_ENVIRON
# SSF_LU_DRIED
# SSF_LU_FACIES_GRADE
# SSF_LU_FREEZE_DRIED
# SSF_LU_GEOLOGIC_AGE
# SSF_LU_GRIND
# SSF_LU_GROUND
# SSF_LU_LAND_COVER
# SSF_LU_LEACH_EXTRACTED_PHASE
# SSF_LU_LEACH_EXTRACTION_REAGENT
# SSF_LU_LEACH_METHOD_COLLECT
# SSF_LU_LEACH_O_MAT_SAMP_SOURCE
# SSF_LU_LEACH_O_MAT_SAMP_TYPE
# SSF_LU_LEACH_PARTICLE_SIZE
# SSF_LU_LEACH_SAMP_PRES_METH
# SSF_LU_LEACH_SAMPLE_SOURCE
# SSF_LU_LEACH_SAMPLE_TYPE
# SSF_LU_LEACH_TEMPERATURE
# SSF_LU_LEACH_TIME
# SSF_LU_LIMS_PREP_REQUEST
# SSF_LU_LOCATIONS
# SSF_LU_METAMORPHISM
# SSF_LU_METHOD_COLLECTED
# SSF_LU_MILL
# SSF_LU_MILLED
# SSF_LU_MIN_SPECIFIC_NAME_COPY
# SSF_LU_MINERAL_SOURCE
# SSF_LU_MINERALIZATION
# SSF_LU_MINHOST
# SSF_LU_MISC_SOLID_SPECIFIC_NAME
# SSF_LU_MISC_SOURCE
# SSF_LU_MISC_SPECIFICNAME
# SSF_LU_MISCMASTER
# SSF_LU_NEW_COLL_PROTOCOLS
# SSF_LU_ORG_COAL_COMP_TREATMENT
# SSF_LU_ORG_OTHER_TREAT_COMPLETE
# SSF_LU_ORG_PREP_COMPLETE
# SSF_LU_ORGANIC_ANIMAL_PART
# SSF_LU_ORGANIC_ANIMAL_SOURCE
# SSF_LU_ORGANIC_COAL_RANK
# SSF_LU_ORGANIC_COAL_SOURCE
# SSF_LU_ORGANIC_MISC_SOURCE
# SSF_LU_ORGANIC_PLANT_PART
# SSF_LU_ORGANIC_PLANT_SOURCE
# SSF_LU_ORGANIC_PLANT_TYPE
# SSF_LU_PORESIZE
# SSF_LU_REQUEST_4_PREP
# SSF_LU_ROCK_SAMPLE_SOURCE
# SSF_LU_ROCK_TYPE
# SSF_LU_ROCKGRIND
# SSF_LU_ROCKMASTER
# SSF_LU_SAMPLE_TYPE
# SSF_LU_SAMPLING_ZONE
# SSF_LU_SEDIMENT_SAMPLE_SOURCE
# SSF_LU_SEDIMENTCOMPLETEDTREATMEN
# SSF_LU_SEDIMENTMASTER
# SSF_LU_SIEVE
# SSF_LU_SIEVE_SIZE
# SSF_LU_SIEVED
# SSF_LU_SOIL_DRAINAGE
# SSF_LU_SOIL_FERRITIC
# SSF_LU_SOIL_HORIZONS
# SSF_LU_SOIL_MOISTURE
# SSF_LU_SOIL_ORGANICS
# SSF_LU_SOIL_SALINITY
# SSF_LU_SOILGRIND
# SSF_LU_SPECIFIC_NAME
# SSF_LU_SPECIFIC_SAMPLE_TYPE
# SSF_LU_STABILIZATION_AGENT
# SSF_LU_STATE
# SSF_LU_STRUCT_SAMPLE_SRC
# SSF_LU_TEMP_UNIT
# SSF_LU_WASH
# SSF_LU_WASHED
# SSF_LU_WATER_ALKALINITY_UNIT
# SSF_LU_WATER_COLL_PROTOCOL
# SSF_LU_WATER_COND_UNIT
# SSF_LU_WATER_DISS_O2_UNIT
# SSF_LU_WATER_METHOD_COLLECTED
# SSF_LU_WATER_SAMPLE_TYPE
# SSF_LU_WATER_SAMPLESOURCE
# SSF_SSF_LU_LOOKUP_TABLES
# Master_TableDescriptions
# SSF_LU_COLLECTION_PROTOCOL
# SSF_LU_FROZEN
# SSF_LU_LEACH_METHOD
# SSF_LU_LEACH_SPECIFIC_NAME
# SSF_LU_MIN_SPECIFIC_NAME
# SSF_LU_MISC_LIQUID_SPECIFIC_NAME
# SSF_LU_ORG_SAMPLE_TYPE
# SSF_LU_PARENT_MATERIAL
# SSF_LU_SAMPLESOURCE

# %%
mdb.read_table("../data/WBSSS_Lookup_Tables.accdb", "SSF_LU_GEOLOGIC_AGE")
# Out:
#                     GEOLOGIC_AGE  SORT_ORDER  SEQ
# 0                        unknown        30.0   27
# 1   precambrian undifferentiated        29.0   26
# 2   proterozoic undifferentiated        26.0   23
# 3                 neoproterozoic        23.0   24
# 4                mesoproterozoic        24.0   25
# 5     paleozoic undifferentiated        22.0   22
# 6                       cambrian        21.0   21
# 7                     ordovician        20.0   20
# 8                       silurian        19.0   19
# 9                       devonian        18.0   18
# 10                 mississippian        16.0   16
# 11                 pennsylvanian        15.0   15
# 12                       permian        14.0   14
# 13     mesozoic undifferentiated        13.0   13
# 14                      triassic        12.0   12
# 15                      jurassic        11.0   11
# 16                    cretaceous        10.0   10
# 17     tertiary undifferentiated         9.0    9
# 18                     paleocene         8.0    8
# 19                        eocene         7.0    7
# 20                     oligocene         6.0    6
# 21                       miocene         5.0    5
# 22                      pliocene         4.0    4
# 23   quaternary undifferentiated         3.0    3
# 24                   pleistocene         2.0    2
# 25                      holocene         1.0    1
# 26              paleoproterozoic        25.0   28
# 27                 carboniferous        17.0   17
# 28                       archean        27.0   29
# 29                        hadean        28.0   30

# %%
lims_rocks = pd.read_excel('../data/SSF_LU_SPECIFIC_NAME.xlsx')

# %%
lims_rocks[~lims_rocks['SPECIFIC_NAME'].isin(geokb_rocks['rockLabel'])]
# Out:
#      SORT_ORDER PRIMARY_CLASS SECONDARY_CLASS         SPECIFIC_NAME  \
# 0             1          rock         igneous  igneous unidentified
# 3             5          rock         igneous             intrusive
# 6            13          rock         igneous          syenodiorite
# 12           22          rock         igneous               diabase
# 13           23          rock         igneous              dolerite
# ..          ...           ...             ...                   ...
# 272         711          rock   miscellaneous                nodule
# 273         712          rock   miscellaneous                 ochre
# 275         714          rock   miscellaneous           psilomelane
# 278         720          rock     sedimentary              paleosol
# 280         999          rock    unidentified          unidentified
#
#                                            DESCRIPTION  SEQ
# 0                                       rock > igneous   28
# 3                rock > igneous > plutonic > intrusive   31
# 6    rock > igneous > plutonic > dioritoid > diorit...   34
# 12      rock > igneous > plutonic > gabbroid > diabase   40
# 13     rock > igneous > plutonic > gabbroid > dolerite   41
# ..                                                 ...  ...
# 272                      rock > miscellaneous > nodule   21
# 273                       rock > miscellaneous > ochre   22
# 275                 rock > miscellaneous > psilomelane   24
# 278            rock > sedimentary > clastic > paleosol  288
# 280                                               rock   27
#
# [95 rows x 6 columns]

# %%
geokb_mapping = geokb_rocks[geokb_rocks['rockLabel'].notnull()].drop_duplicates().set_index('rockLabel')['rock'].to_dict()
geokb_mapping.update(geokb_rocks[geokb_rocks['rock_alt_label'].notnull()].drop_duplicates().set_index('rock_alt_label')['rock'].to_dict())

gso_mapping = geokb_rocks[geokb_rocks['same_as'].str.contains('w3id.org')].drop_duplicates().set_index('rockLabel')['same_as'].to_dict()
gso_mapping.update(geokb_rocks[geokb_rocks['same_as'].str.contains('w3id.org') & geokb_rocks['rock_alt_label'].notnull()].drop_duplicates().set_index('rock_alt_label')['same_as'].to_dict())

mindat_mapping = geokb_rocks[geokb_rocks['same_as'].str.contains('mindat.org')].drop_duplicates().set_index('rockLabel')['same_as'].to_dict()
mindat_mapping.update(geokb_rocks[geokb_rocks['same_as'].str.contains('mindat.org') & geokb_rocks['rock_alt_label'].notnull()].drop_duplicates().set_index('rock_alt_label')['same_as'].to_dict())

# %%
lims_rocks['geokb_link'] = lims_rocks['SPECIFIC_NAME'].map(geokb_mapping)
lims_rocks['gso_link'] = lims_rocks['SPECIFIC_NAME'].map(gso_mapping)
lims_rocks['mindat_link'] = lims_rocks['SPECIFIC_NAME'].map(mindat_mapping)

# %%
lims_rocks
# Out:
#      SORT_ORDER PRIMARY_CLASS SECONDARY_CLASS         SPECIFIC_NAME  \
# 0             1          rock         igneous  igneous unidentified
# 1             2          rock         igneous              aphanite
# 2             3          rock         igneous               felsite
# 3             5          rock         igneous             intrusive
# 4            10          rock         igneous             dioritoid
# ..          ...           ...             ...                   ...
# 276         715          rock   miscellaneous                sinter
# 277         716          rock   miscellaneous               tektite
# 278         720          rock     sedimentary              paleosol
# 279         725          rock     sedimentary                  coal
# 280         999          rock    unidentified          unidentified
#
#                                  DESCRIPTION  SEQ  \
# 0                             rock > igneous   28
# 1      rock > igneous > aphanitic > aphanite   29
# 2       rock > igneous > aphanitic > felsite   30
# 3      rock > igneous > plutonic > intrusive   31
# 4      rock > igneous > plutonic > dioritoid   32
# ..                                       ...  ...
# 276            rock > miscellaneous > sinter   25
# 277           rock > miscellaneous > tektite   26
# 278  rock > sedimentary > clastic > paleosol  288
# 279      rock > sedimentary > organic > coal  289
# 280                                     rock   27
#
#                                      geokb_link  \
# 0                                           NaN
# 1    https://geokb.wikibase.cloud/entity/Q43299
# 2    https://geokb.wikibase.cloud/entity/Q41790
# 3                                           NaN
# 4    https://geokb.wikibase.cloud/entity/Q41608
# ..                                          ...
# 276  https://geokb.wikibase.cloud/entity/Q41428
# 277  https://geokb.wikibase.cloud/entity/Q41390
# 278                                         NaN
# 279  https://geokb.wikibase.cloud/entity/Q41370
# 280                                         NaN
#
#                                         gso_link  \
# 0                                            NaN
# 1     https://w3id.org/gso/rockmaterial/aphanite
# 2                                            NaN
# 3                                            NaN
# 4    https://w3id.org/gso/rockmaterial/dioritoid
# ..                                           ...
# 276                                          NaN
# 277                                          NaN
# 278                                          NaN
# 279       https://w3id.org/gso/rockmaterial/coal
# 280                                          NaN
#
#                            mindat_link
# 0                                  NaN
# 1    https://mindat.org/min-50628.html
# 2    https://mindat.org/min-48445.html
# 3                                  NaN
# 4    https://mindat.org/min-48224.html
# ..                                 ...
# 276  https://mindat.org/min-49378.html
# 277  https://mindat.org/min-10859.html
# 278                                NaN
# 279   https://mindat.org/min-9353.html
# 280                                NaN
#
# [281 rows x 9 columns]

# %%
lims_rocks.fillna('').to_excel('../data/SSF_LU_SPECIFIC_NAME_linkages.xlsx', index=False)
