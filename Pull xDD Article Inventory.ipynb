# %% [markdown]
# This notebook works to baseline the connection between USGS Series Reports in the USGS Publications Warehouse and the xDD (GeoDeepDive) infrastructure. The USGS reports have been picked up and processed through xDD for some time now as one of many collections of scientific articles worked through the xDD AI pipelines. They are in a collection indicated by "USGS" as publisher. We need to connect dots between the various places and pieces of infrastructure where we have these reports documented and are working with them and the xDD "digestion" of these contents so that we can better exploit what the xDD pipelines have produced. To do that, we need to work out the linkage between our own base identifiers and the "gddid" for the articles that is our key to tapping the various xDD APIs and working up specific NLP processing.
#
# There are some challenges we need to work through in this due to a change that occurred some time back in how the xDD framework fetches USGS report metadata. This started off via ScienceBase and it's representation of USGS report metadata when the ScienceBase API provided a better route to operate against. Once the Pubs Warehouse web services became more mature, we switched to that route. However, this introduced some difference in how the "articles" are represented in xDD and the available information we can link through. Part of the work in this notebook is to hash out that issue, baseline the connection from "xDD articles" to Pubs Warehouse entities, and point out where we can make improvements to bring cohesion and interoperability moving forward. On the USGS side, we have a metadata element in the Pubs Warehouse Catalog schema to accommodate the "gddid" from xDD, and we'll be getting that in place and working out how to keep it maintained through this work.

# %%
import requests
import pandas as pd
from urllib.parse import urlparse, parse_qs

# %% [markdown]
# Here we need to work through the "scan-and-scroll" method supported by the xDD articles API to fetch all basic item metadata for the USGS publisher so that we can go through it to develop the linkage to our Pubs Warehouse base records and identify areas where we can improve the metadata in xDD for better alignment with our own systems.

# %%
publisher = "USGS"
xdd_articles_api = f"https://geodeepdive.org/api/articles?publisher={publisher}&full_results"

all_records = []
next_page = xdd_articles_api
page_num = 1
while next_page:
    response = requests.get(next_page).json()
    if "success" in response and "data" in response["success"]:
        print("PROCESSING", len(response["success"]["data"]), "FROM PAGE NUMBER", page_num, "RECORDS OF", response["success"]["hits"])
        all_records.extend(response["success"]["data"])
        if "next_page" in response["success"]:
            next_page = response["success"]["next_page"]
            page_num+=1
        else:
            break
    else:
        break
# Out:
# PROCESSING 500 FROM PAGE NUMBER 1 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 2 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 3 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 4 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 5 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 6 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 7 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 8 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 9 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 10 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 11 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 12 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 13 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 14 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 15 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 16 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 17 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 18 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 19 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 20 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 21 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 22 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 23 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 24 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 25 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 26 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 27 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 28 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 29 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 30 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 31 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 32 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 33 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 34 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 35 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 36 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 37 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 38 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 39 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 40 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 41 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 42 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 43 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 44 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 45 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 46 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 47 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 48 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 49 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 50 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 51 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 52 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 53 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 54 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 55 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 56 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 57 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 58 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 59 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 60 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 61 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 62 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 63 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 64 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 65 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 66 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 67 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 68 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 69 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 70 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 71 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 72 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 73 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 74 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 75 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 76 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 77 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 78 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 79 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 80 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 81 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 82 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 83 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 84 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 85 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 86 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 87 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 88 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 89 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 90 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 91 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 92 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 93 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 94 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 95 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 96 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 97 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 98 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 99 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 100 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 101 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 102 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 103 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 104 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 105 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 106 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 107 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 108 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 109 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 110 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 111 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 112 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 113 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 114 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 115 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 116 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 117 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 118 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 119 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 120 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 121 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 122 RECORDS OF 63976
# PROCESSING 500 FROM PAGE NUMBER 123 RECORDS OF 63976
# PROCESSING 498 FROM PAGE NUMBER 124 RECORDS OF 63976
# PROCESSING 467 FROM PAGE NUMBER 125 RECORDS OF 63976
# PROCESSING 393 FROM PAGE NUMBER 126 RECORDS OF 63976
# PROCESSING 312 FROM PAGE NUMBER 127 RECORDS OF 63976
# PROCESSING 256 FROM PAGE NUMBER 128 RECORDS OF 63976
# PROCESSING 184 FROM PAGE NUMBER 129 RECORDS OF 63976
# PROCESSING 139 FROM PAGE NUMBER 130 RECORDS OF 63976
# PROCESSING 100 FROM PAGE NUMBER 131 RECORDS OF 63976
# PROCESSING 55 FROM PAGE NUMBER 132 RECORDS OF 63976
# PROCESSING 32 FROM PAGE NUMBER 133 RECORDS OF 63976
# PROCESSING 20 FROM PAGE NUMBER 134 RECORDS OF 63976
# PROCESSING 20 FROM PAGE NUMBER 135 RECORDS OF 63976

# %%
df_usgs_xdd_collection = pd.DataFrame(all_records)

# %%
df_usgs_xdd_collection.head()
# Out:
#        type                    _gddid  \
# 0  fulltext  5a8dbacfcf58f1815e19f708
# 1  fulltext  5a8dbad0cf58f1815e19f70e
# 2  fulltext  5a8dbac9cf58f1815e19f700
# 3  fulltext  5a8dbad7cf58f1815e19f717
# 4  fulltext  559dcd86e138230816dad9c0
#
#                                                title volume           journal  \
# 0  Grover Heinrichs mining collection: Copper Cre...
# 1  Grover Heinrichs mining collection: Exxon Company
# 2  Grover Heinrichs mining collection: Leadville ...
# 3                       Vulture: Various Cost sheets
# 4  Program disk to accompany MAGMIX (Computers &a...         Open-File Report
#
#                                                 link  \
# 0  [{'url': 'https://www.sciencebase.gov/catalog/...
# 1  [{'url': 'https://www.sciencebase.gov/catalog/...
# 2  [{'url': 'https://www.sciencebase.gov/catalog/...
# 3  [{'url': 'https://www.sciencebase.gov/catalog/...
# 4  [{'url': 'https://pubs.er.usgs.gov/publication...
#
#                          publisher abstract  \
# 0                             USGS
# 1                             USGS
# 2                             USGS
# 3                             USGS
# 4  United States Geological Survey      NaN
#
#                                               author pages number  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'name': 'Frost, T.P.'}, {'name': 'Lindsay, J...
#
#                                     identifier  year cited_by
# 0                                           []  2016      NaN
# 1                                           []  2016      NaN
# 2                                           []  2016      NaN
# 3                                           []  2015      NaN
# 4  [{'type': 'doi', 'id': '10.3133/ofr88501'}]  1988      NaN

# %%
xdd_article_links = df_usgs_xdd_collection[df_usgs_xdd_collection.link.str.len() > 0][["_gddid","link"]].explode("link")
xdd_article_links["url"] = xdd_article_links["link"].apply(lambda x: x["url"])
xdd_article_links.drop(columns="link", inplace=True)

xdd_article_links['domain'] = xdd_article_links['url'].apply(lambda x: urlparse(x).netloc)
xdd_article_links['path'] = xdd_article_links['url'].apply(lambda x: urlparse(x).path)
xdd_article_links['scheme'] = xdd_article_links['url'].apply(lambda x: urlparse(x).scheme)
xdd_article_links['params'] = xdd_article_links['url'].apply(lambda x: parse_qs(urlparse(x).query))

# %%
xdd_article_links.domain.unique()
# Out:
# array(['www.sciencebase.gov', 'pubs.er.usgs.gov', 'pubs.usgs.gov',
#        'ngmdb.usgs.gov', 'ks.water.usgs.gov', 'pubs.water.usgs.gov',
#        'www.dggs.dnr.state.ak.us', 'www.archive.org', 'wi.water.usgs.gov',
#        'or.water.usgs.gov', 'water.usgs.gov', 'il.water.usgs.gov',
#        'www.webharvest.gov', 'sofia.usgs.gov', 'ca.water.usgs.gov',
#        'mo.water.usgs.gov', 'ky.water.usgs.gov', 'smig.usgs.gov',
#        'nwql.usgs.gov', 'repository.agic.umn.edu', 'md.water.usgs.gov',
#        'ny.water.usgs.gov', 'www.usgs.gov', 'mn.water.usgs.gov',
#        'vulcan.wr.usgs.gov', 'nd.water.usgs.gov', 'ne.water.usgs.gov',
#        'wwwsd.cr.usgs.gov', 'fl.water.usgs.gov', 'geology.er.usgs.gov',
#        'pa.water.usgs.gov', 'pr.water.usgs.gov', 'www.nps.gov',
#        'gulfsci.usgs.gov', 'quake.wr.usgs.gov', 'nsmp.wr.usgs.gov',
#        'wa.water.usgs.gov', 'mi.water.usgs.gov', 'toxics.usgs.gov',
#        'dggs.alaska.gov', 'coastal.er.usgs.gov', 'astrogeology.usgs.gov',
#        'bqs.usgs.gov', 'erg.usgs.gov', 'marine.usgs.gov',
#        'mcmcweb.er.usgs.gov', 'ms.water.usgs.gov', 'az.water.usgs.gov',
#        'tn.water.usgs.gov', 'wwwbrr.cr.usgs.gov',
#        'permanent.access.gpo.gov', 'geology.cr.usgs.gov', 'ny.usgs.gov',
#        'sfbay.wr.usgs.gov', 'hvo.wr.usgs.gov', 'ma.water.usgs.gov',
#        'biology.usgs.gov', 'greenwood.cr.usgs.gov', 'energy.cr.usgs.gov',
#        'crusty.er.usgs.gov', 'www-ks.cr.usgs.gov',
#        'woodshole.er.usgs.gov', 'www2.usgs.gov', 'ia.water.usgs.gov',
#        'speclab.cr.usgs.gov', 'sofia.er.usgs.gov', 'geology.usgs.gov',
#        'archive.usgs.gov'], dtype=object)

# %%
xdd_article_identifiers = df_usgs_xdd_collection[df_usgs_xdd_collection.identifier.str.len() > 0][["_gddid","identifier"]].explode("identifier")
xdd_article_identifiers["doi"] = xdd_article_identifiers["identifier"].apply(lambda x: x["id"])
xdd_article_identifiers.drop(columns="identifier", inplace=True)

# %% [markdown]
# We've got some duplicate DOIs in the xDD system, which I would not necessarily expect. This may be do to some of the ways we've used DOIs to resolve to collections vs. individual articles. I'll have to dig into these further, but for now we can really only work through the unique DOIs.

# %%
ids = xdd_article_identifiers["doi"]
duplicate_dois = xdd_article_identifiers[ids.isin(ids[ids.duplicated()])].sort_values("doi")
unique_dois = xdd_article_identifiers.drop_duplicates(subset="doi", keep=False)

# %% [markdown]
# # Interim Tangent
#
# I'm shortcutting the process toward a comprehensive linkage between all Pubs Warehouse Catalog entities and associated xDD entities to see if we can get some immediate connections between the handful of reports we have represented in the GeoKB and get thost properties in place. Even though this is a tangent here, the same basic process should work to gather the lion's share of linkages from Pubs Warehouse reposited USGS reports to xDD representations. Given truly unique, single item DOIs (mostly in the 10.3133 identifier space) from xDD, we should be able to pull GDDIDs into the Pubs Warehouse catalog as a baseline. We'll then need to work out a process to pick up new identifiers once processing is complete on whatever schedule the xDD pipelines are operating. We might, perhaps, look toward something old school like an RSS feed, though that doesn't exist yet on the xDD side to my knowledge.

# %%
from wbmaker import WikibaseConnection

# %%
geokb = WikibaseConnection("GEOKB_CLOUD")

# %%
geokb_usgs_reports = geokb.url_sparql_query(
    sparql_url="https://geokb.wikibase.cloud/query/sparql?query=PREFIX%20wd%3A%20%3Chttps%3A%2F%2Fgeokb.wikibase.cloud%2Fentity%2F%3E%0APREFIX%20wdt%3A%20%3Chttps%3A%2F%2Fgeokb.wikibase.cloud%2Fprop%2Fdirect%2F%3E%0A%0ASELECT%20%3Fitem%20%3Fdoi%20%3Fgddid%0AWHERE%20%7B%0A%20%20%3Fitem%20wdt%3AP1%2Fwdt%3AP2*%20wd%3AQ11%20.%0A%20%20%3Fitem%20wdt%3AP74%20%3Fdoi%20.%0A%20%20OPTIONAL%20%7B%0A%20%20%20%20%3Fitem%20wdt%3AP93%20%3Fgddid%20.%0A%20%20%7D%0A%7D",
    output_format="dataframe"
)
geokb_usgs_reports["qid"] = geokb_usgs_reports["item"].apply(lambda x: x.split("/")[-1])

# %%
geokb_doi_to_gddid = pd.merge(
    left=geokb_usgs_reports[geokb_usgs_reports.doi.isin(unique_dois.doi)],
    right=unique_dois,
    how="left",
    on="doi"
)

# %%
geokb_doi_to_gddid.head(10)
# Out:
#                                          item              doi  \
# 0  https://geokb.wikibase.cloud/entity/Q54997  10.3133/mf2198E
# 1  https://geokb.wikibase.cloud/entity/Q54999  10.3133/mf2198D
# 2  https://geokb.wikibase.cloud/entity/Q55001  10.3133/mf2198C
# 3  https://geokb.wikibase.cloud/entity/Q55033  10.3133/mf1985B
# 4  https://geokb.wikibase.cloud/entity/Q55053  10.3133/mf2021F
# 5  https://geokb.wikibase.cloud/entity/Q55069  10.3133/mf1996A
# 6  https://geokb.wikibase.cloud/entity/Q55183   10.3133/cir718
# 7  https://geokb.wikibase.cloud/entity/Q55188  10.3133/cir930D
# 8  https://geokb.wikibase.cloud/entity/Q55190   10.3133/cir901
# 9  https://geokb.wikibase.cloud/entity/Q55192  10.3133/cir930A
#
#                       gddid     qid                    _gddid
# 0  5d2411d30b45c76caf91efe9  Q54997  5d2411d30b45c76caf91efe9
# 1  5d2411d30b45c76caf91efe3  Q54999  5d2411d30b45c76caf91efe3
# 2  5d2411d30b45c76caf91efea  Q55001  5d2411d30b45c76caf91efea
# 3  5da285b1998e17af825362e8  Q55033  5da285b1998e17af825362e8
# 4  5d4ea46e0b45c76cafa444df  Q55053  5d4ea46e0b45c76cafa444df
# 5  557f9100e13823bc80ba2755  Q55069  557f9100e13823bc80ba2755
# 6  55b8969ce13823bd29ba8893  Q55183  55b8969ce13823bd29ba8893
# 7                      None  Q55188  5d24fa060b45c76caf9212c0
# 8                      None  Q55190  55b8f208e13823bd29ba8b0a
# 9                      None  Q55192  55b8f0c4e13823bd29ba8b01

# %%
for index, row in geokb_doi_to_gddid[geokb_doi_to_gddid["gddid"].isnull()].iterrows():
    item = geokb.wbi.item.get(row["qid"])

    api_ref = geokb.models.References()
    api_ref.add(
        geokb.datatypes.URL(
            prop_nr=geokb.prop_lookup["reference URL"],
            value=f"https://geodeepdive.org/api/articles?doi={row['doi']}"
        )
    )

    item.claims.add(
        geokb.datatypes.ExternalID(
            prop_nr=geokb.prop_lookup["GDDID"],
            value=row["_gddid"],
            references=api_ref
        )
    )

    response = item.write(
        summary="Added GDDID based on DOI match via xDD articles API"
    )
    print(response.id)
