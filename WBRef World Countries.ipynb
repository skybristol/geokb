# %% [markdown]
# This notebook works through one method of building out initial world country items that I'll have to improve on. It is simple the ISO 3166-1 set of codes and country names. As we work out what all information about countries we need the GeoKB to contain, we can pull additional information via these codes from Wikidata or other sources. I used the expedient of getting at the ISO country list via the pycountry package, which leverages the Debian ISO database.
#
# As we dig deeper into what we need to link with in terms of political boundaries in other countries, we may want to revisit this from the standpoint of subdivisions identified with ISO 3166-2 codes. The challenge there will be classifying those in some useful way as each country uses their own classification system (e.g., London boroughs, Unitary areas, etc. in GB). For now, we'll leave those out, using the U.S. Census sources for subdivions in the U.S.

# %%
import pycountry
from wbmaker import WikibaseConnection

# %%
geokb = WikibaseConnection("GEOKB_CLOUD")

# %%
def lookup_country(iso_alpha):
    q = """
    %(namespaces)s

    SELECT ?st ?iso_alpha
    WHERE {
    # ?st wdt:%(p_iso_alpha)s "%(v_iso_alpha)s" .
    # ?st wdt:%(p_iso_alpha)s ?iso_alpha .
    SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
    }
    """ % {
        "namespaces": geokb.sparql_namespaces(),
        "v_iso_alpha": iso_alpha,
        "p_iso_alpha": geokb.prop_lookup['ISO 3166-1 alpha-2 code']
    }

    return geokb.sparql_query(query=q, output="lookup")

# %%
for c in pycountry.countries:
    c_lookup = lookup_country(c.alpha_2)
    if c_lookup:
        item = geokb.wbi.item.get(c_lookup[c.alpha_2])
    else:
        item = geokb.wbi.item.new()

    aliases = []
    try:
        item.labels.set('en', c.official_name)
        aliases.append(c.name)
    except:
        item.labels.set('en', c.name)

    aliases.extend([c.alpha_2, c.alpha_3])
    item.aliases.set('en', aliases)

    item.descriptions.set('en', 'a world country item')

    claims = geokb.models.Claims()
    
    claims.add(
        geokb.datatypes.Item(
            prop_nr=geokb.prop_lookup['instance of'],
            value=geokb.class_lookup['country']
        )
    )

    claims.add(
        geokb.datatypes.ExternalID(
            prop_nr=geokb.prop_lookup['ISO 3166-1 alpha-2 code'],
            value=c.alpha_2
        )
    )
    
    claims.add(
        geokb.datatypes.ExternalID(
            prop_nr=geokb.prop_lookup['ISO 3166-1 alpha-3 code'],
            value=c.alpha_3
        )
    )

    claims.add(
        geokb.datatypes.ExternalID(
            prop_nr=geokb.prop_lookup['ISO 3166-1 numeric code'],
            value=c.numeric
        )
    )

    item.claims.add(claims)

    response = item.write(
        summary="Updated item from pycountry",
        clear=True
    )
    print("UPDATED:", c.name, response.id)
# Out:
# UPDATED: Aruba Q153
# UPDATED: Afghanistan Q103
# UPDATED: Angola Q106
# UPDATED: Anguilla Q26702
# UPDATED: Åland Islands Q26703
# UPDATED: Albania Q196
# UPDATED: Andorra Q199
# UPDATED: United Arab Emirates Q100
# UPDATED: Argentina Q37
# UPDATED: Armenia Q35
# UPDATED: American Samoa Q26704
# UPDATED: Antarctica Q26705
# UPDATED: French Southern Territories Q26706
# UPDATED: Antigua and Barbuda Q72
# UPDATED: Australia Q36
# UPDATED: Austria Q171
# UPDATED: Azerbaijan Q197
# UPDATED: Burundi Q119
# UPDATED: Belgium Q26707
# UPDATED: Benin Q117
# UPDATED: Bonaire, Sint Eustatius and Saba Q26708
# UPDATED: Burkina Faso Q120
# UPDATED: Bangladesh Q104
# UPDATED: Bulgaria Q195
# UPDATED: Bahrain Q34
# UPDATED: Bahamas Q70
# UPDATED: Bosnia and Herzegovina Q26709
# UPDATED: Saint Barthélemy Q26710
# UPDATED: Belarus Q187
# UPDATED: Belize Q26711
# UPDATED: Bermuda Q26712
# UPDATED: Bolivia, Plurinational State of Q62
# UPDATED: Brazil Q184
# UPDATED: Barbados Q26713
# UPDATED: Brunei Darussalam Q108
# UPDATED: Bhutan Q107
# UPDATED: Bouvet Island Q26714
# UPDATED: Botswana Q118
# UPDATED: Central African Republic Q111
# UPDATED: Canada Q157
# UPDATED: Cocos (Keeling) Islands Q26715
# UPDATED: Switzerland Q167
# UPDATED: Chile Q31
# UPDATED: China Q183
# UPDATED: Côte d'Ivoire Q130
# UPDATED: Cameroon Q131
# UPDATED: Congo, The Democratic Republic of the Q123
# UPDATED: Congo Q122
# UPDATED: Cook Islands Q155
# UPDATED: Colombia Q60
# UPDATED: Comoros Q121
# UPDATED: Cabo Verde Q129
# UPDATED: Costa Rica Q79
# UPDATED: Cuba Q204
# UPDATED: Curaçao Q26716
# UPDATED: Christmas Island Q26717
# UPDATED: Cayman Islands Q26718
# UPDATED: Cyprus Q200
# UPDATED: Czechia Q193
# UPDATED: Germany Q186
# UPDATED: Djibouti Q124
# UPDATED: Dominica Q74
# UPDATED: Denmark Q164
# UPDATED: Dominican Republic Q73
# UPDATED: Algeria Q29
# UPDATED: Ecuador Q61
# UPDATED: Egypt Q175
# UPDATED: Eritrea Q125
# UPDATED: Western Sahara Q26719
# UPDATED: Spain Q26720
# UPDATED: Estonia Q188
# UPDATED: Ethiopia Q179
# UPDATED: Finland Q165
# UPDATED: Fiji Q56
# UPDATED: Falkland Islands (Malvinas) Q26721
# UPDATED: France Q181
# UPDATED: Faroe Islands Q26722
# UPDATED: Micronesia, Federated States of Q52
# UPDATED: Gabon Q26723
# UPDATED: United Kingdom Q182
# UPDATED: Georgia Q26724
# UPDATED: Guernsey Q26725
# UPDATED: Ghana Q180
# UPDATED: Gibraltar Q26726
# UPDATED: Guinea Q126
# UPDATED: Guadeloupe Q26727
# UPDATED: Gambia Q128
# UPDATED: Guinea-Bissau Q127
# UPDATED: Equatorial Guinea Q26728
# UPDATED: Greece Q172
# UPDATED: Grenada Q68
# UPDATED: Greenland Q26729
# UPDATED: Guatemala Q69
# UPDATED: French Guiana Q26730
# UPDATED: Guam Q26731
# UPDATED: Guyana Q58
# UPDATED: Hong Kong Q26732
# UPDATED: Heard Island and McDonald Islands Q26733
# UPDATED: Honduras Q71
# UPDATED: Croatia Q198
# UPDATED: Haiti Q75
# UPDATED: Hungary Q162
# UPDATED: Indonesia Q205
# UPDATED: Isle of Man Q26734
# UPDATED: India Q44
# UPDATED: British Indian Ocean Territory Q26735
# UPDATED: Ireland Q160
# UPDATED: Iran, Islamic Republic of Q76
# UPDATED: Iraq Q78
# UPDATED: Iceland Q189
# UPDATED: Israel Q80
# UPDATED: Italy Q166
# UPDATED: Jamaica Q67
# UPDATED: Jersey Q26736
# UPDATED: Jordan Q82
# UPDATED: Japan Q158
# UPDATED: Kazakhstan Q201
# UPDATED: Kenya Q178
# UPDATED: Kyrgyzstan Q84
# UPDATED: Cambodia Q40
# UPDATED: Kiribati Q53
# UPDATED: Saint Kitts and Nevis Q65
# UPDATED: Korea, Republic of Q102
# UPDATED: Kuwait Q26737
# UPDATED: Lao People's Democratic Republic Q85
# UPDATED: Lebanon Q86
# UPDATED: Liberia Q132
# UPDATED: Libya Q135
# UPDATED: Saint Lucia Q66
# UPDATED: Liechtenstein Q33
# UPDATED: Sri Lanka Q94
# UPDATED: Lesotho Q133
# UPDATED: Lithuania Q169
# UPDATED: Luxembourg Q26738
# UPDATED: Latvia Q190
# UPDATED: Macao Q26739
# UPDATED: Saint Martin (French part) Q26740
# UPDATED: Morocco Q139
# UPDATED: Monaco Q26741
# UPDATED: Moldova, Republic of Q26742
# UPDATED: Madagascar Q134
# UPDATED: Maldives Q87
# UPDATED: Mexico Q177
# UPDATED: Marshall Islands Q55
# UPDATED: North Macedonia Q26743
# UPDATED: Mali Q105
# UPDATED: Malta Q202
# UPDATED: Myanmar Q88
# UPDATED: Montenegro Q203
# UPDATED: Mongolia Q54
# UPDATED: Northern Mariana Islands Q152
# UPDATED: Mozambique Q140
# UPDATED: Mauritania Q137
# UPDATED: Montserrat Q26744
# UPDATED: Martinique Q26745
# UPDATED: Mauritius Q26746
# UPDATED: Malawi Q136
# UPDATED: Malaysia Q26747
# UPDATED: Mayotte Q26748
# UPDATED: Namibia Q138
# UPDATED: New Caledonia Q26749
# UPDATED: Niger Q141
# UPDATED: Norfolk Island Q26750
# UPDATED: Nigeria Q142
# UPDATED: Nicaragua Q83
# UPDATED: Niue Q206
# UPDATED: Netherlands Q174
# UPDATED: Norway Q159
# UPDATED: Nepal Q89
# UPDATED: Nauru Q51
# UPDATED: New Zealand Q43
# UPDATED: Oman Q90
# UPDATED: Pakistan Q91
# UPDATED: Panama Q26751
# UPDATED: Pitcairn Q26752
# UPDATED: Peru Q38
# UPDATED: Philippines Q110
# UPDATED: Palau Q50
# UPDATED: Papua New Guinea Q49
# UPDATED: Poland Q168
# UPDATED: Puerto Rico Q26753
# UPDATED: Korea, Democratic People's Republic of Q39
# UPDATED: Portugal Q173
# UPDATED: Paraguay Q59
# UPDATED: Palestine, State of Q26754
# UPDATED: French Polynesia Q26755
# UPDATED: Qatar Q92
# UPDATED: Réunion Q26756
# UPDATED: Romania Q194
# UPDATED: Russian Federation Q185
# UPDATED: Rwanda Q145
# UPDATED: Saudi Arabia Q93
# UPDATED: Sudan Q150
# UPDATED: Senegal Q147
# UPDATED: Singapore Q32
# UPDATED: South Georgia and the South Sandwich Islands Q26757
# UPDATED: Saint Helena, Ascension and Tristan da Cunha Q26758
# UPDATED: Svalbard and Jan Mayen Q26759
# UPDATED: Solomon Islands Q48
# UPDATED: Sierra Leone Q148
# UPDATED: El Salvador Q77
# UPDATED: San Marino Q26760
# UPDATED: Somalia Q149
# UPDATED: Saint Pierre and Miquelon Q26761
# UPDATED: Serbia Q26762
# UPDATED: South Sudan Q116
# UPDATED: Sao Tome and Principe Q143
# UPDATED: Suriname Q26763
# UPDATED: Slovakia Q191
# UPDATED: Slovenia Q192
# UPDATED: Sweden Q163
# UPDATED: Eswatini Q26764
# UPDATED: Sint Maarten (Dutch part) Q154
# UPDATED: Seychelles Q146
# UPDATED: Syrian Arab Republic Q95
# UPDATED: Turks and Caicos Islands Q26765
# UPDATED: Chad Q42
# UPDATED: Togo Q112
# UPDATED: Thailand Q98
# UPDATED: Tajikistan Q96
# UPDATED: Tokelau Q26766
# UPDATED: Turkmenistan Q99
# UPDATED: Timor-Leste Q41
# UPDATED: Tonga Q26767
# UPDATED: Trinidad and Tobago Q63
# UPDATED: Tunisia Q113
# UPDATED: Turkey Q170
# UPDATED: Tuvalu Q45
# UPDATED: Taiwan, Province of China Q97
# UPDATED: Tanzania, United Republic of Q109
# UPDATED: Uganda Q144
# UPDATED: Ukraine Q26768
# UPDATED: United States Minor Outlying Islands Q26769
# UPDATED: Uruguay Q176
# UPDATED: United States Q161
# UPDATED: Uzbekistan Q30
# UPDATED: Holy See (Vatican City State) Q26770
# UPDATED: Saint Vincent and the Grenadines Q64
# UPDATED: Venezuela, Bolivarian Republic of Q57
# UPDATED: Virgin Islands, British Q26771
# UPDATED: Virgin Islands, U.S. Q26772
# UPDATED: Viet Nam Q101
# UPDATED: Vanuatu Q47
# UPDATED: Wallis and Futuna Q26773
# UPDATED: Samoa Q46
# UPDATED: Yemen Q81
# UPDATED: South Africa Q28
# UPDATED: Zambia Q115
# UPDATED: Zimbabwe Q114
