# %% [markdown]
# This notebook explores a process of running a SPARQL query in the GeoKB to pull out a graph for analysis and load that into Neo4j where there are some better analytical possibilities for certain inquiries. There are lots of ways of loading data to Neo4j and many ways of organizing the nodes, properties, and edges. This particular example was prompted by a question from folks in the Midcontinent Region who were interested in exploring the co-author connections across Science Centers. We start with a query that pulls all Midcontinent organizational units, the affiliations of people to those organization entities, and the articles those people have authored after 2017. We load all three entity types as nodes with a couple of attributes and then create the relationships between them. I retain the full URL identifier for the QID identities in the GeoKB and mostly stick with the same basic semantics on entity attributes and relationship properties. In the final codeblock, I run a query in Neo4j that produces a table output with the basic interconnection between authors that are working across different Science Centers.

# %%
from neo4j import GraphDatabase

import sys
sys.path.append('../harvesters/')

from wbmaker import WikibaseConnection

# %%
geokb = WikibaseConnection('GEOKB_CLOUD')

# %%
neo4j_driver = GraphDatabase.driver("bolt://localhost:7687")
neo4j_session = neo4j_driver.session()

# %%
query_midcontinent = """
PREFIX ge: <https://geokb.wikibase.cloud/entity/>
PREFIX gp: <https://geokb.wikibase.cloud/prop/direct/>

SELECT ?org ?orgLabel ?orgAltLabel ?orgDescription ?subsidiary_of ?org_instance_ofLabel ?org_website
# ?person ?personLabel ?personAltLabel ?personDescription ?affiliated_with ?person_website
# ?article ?articleLabel ?articleDescription (YEAR(?publication_date) AS ?pub_year) ?doi ?article_instance_ofLabel
WHERE {
  # ?org gp:P190* ge:Q44363 ;
       gp:P190 ?subsidiary_of ;
       gp:P1 ?org_instance_of .
  OPTIONAL {
    # ?org gp:P145 ?org_website .
  }
  # ?person gp:P108 ?org ;
          gp:P108 ?affiliated_with .
  OPTIONAL {
    # ?person gp:P145 ?person_website .
  }
  # ?article gp:P102 ?person ;
           gp:P1 ?article_instance_of ;
           gp:P7 ?publication_date .
  OPTIONAL {
    # ?article gp:P74 ?doi .
  }
  FILTER (YEAR(?publication_date) > 2017)
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
"""

midcontinent_pub_record = geokb.sparql_query(query_midcontinent)

# %%
org_nodes = midcontinent_pub_record[['org', 'orgLabel', 'orgAltLabel', 'orgDescription', 'org_website', 'org_instance_ofLabel']].drop_duplicates().reset_index(drop=True)
person_nodes = midcontinent_pub_record[['person', 'personLabel', 'personAltLabel', 'personDescription', 'person_website']].drop_duplicates().reset_index(drop=True)
article_nodes = midcontinent_pub_record[['article', 'articleLabel', 'articleDescription', 'pub_year', 'doi', 'article_instance_ofLabel']].drop_duplicates().reset_index(drop=True)

org_relationships = midcontinent_pub_record[['org', 'subsidiary_of']].drop_duplicates().reset_index(drop=True)
person_relationships = midcontinent_pub_record[['person', 'affiliated_with']].drop_duplicates().reset_index(drop=True)
article_relationships = midcontinent_pub_record[['article', 'person']].drop_duplicates().reset_index(drop=True)

# %%
org_nodes.head()
# Out:
#                                           org  \
# 0  https://geokb.wikibase.cloud/entity/Q44222
# 1  https://geokb.wikibase.cloud/entity/Q44228
# 2  https://geokb.wikibase.cloud/entity/Q44248
# 3  https://geokb.wikibase.cloud/entity/Q44256
# 4  https://geokb.wikibase.cloud/entity/Q44246
#
#                                          orgLabel  \
# 0          Northern Rocky Mountain Science Center
# 1                      Great Lakes Science Center
# 2  Earth Resources Observation and Science Center
# 3       Northern Prairie Wildlife Research Center
# 4                     Dakota Water Science Center
#
#                                          orgAltLabel  \
# 0                                               None
# 1                                               GLSC
# 2  Earth Resources Observation and Science (EROS)...
# 3                                               None
# 4  North Dakota Water Science Center, South Dakot...
#
#                 orgDescription  \
# 0        A USGS Science Center
# 1        A USGS Science Center
# 2        A USGS Science Center
# 3        A USGS Science Center
# 4  A USGS Water Science Center
#
#                                          org_website  \
# 0                https://www.usgs.gov/centers/norock
# 1  https://www.usgs.gov/centers/great-lakes-scien...
# 2                  https://www.usgs.gov/centers/eros
# 3  https://www.usgs.gov/centers/northern-prairie-...
# 4          https://www.usgs.gov/centers/dakota-water
#
#         org_instance_ofLabel
# 0        USGS Science Center
# 1        USGS Science Center
# 2        USGS Science Center
# 3        USGS Science Center
# 4  USGS Water Science Center

# %%
for _, row in org_nodes.iterrows():
    neo4j_session.run("""
        MERGE (n:Organization {id: $id})
        ON CREATE SET n.label = $label,
                      n.altLabel = $altLabel,
                      n.description = $description,
                      n.website = $website,
                      n.instance_of = $instance_of
        """, 
        id=row['org'], 
        label=row['orgLabel'], 
        altLabel=row['orgAltLabel'], 
        description=row['orgDescription'],
        website=row['org_website'], 
        instance_of=row['org_instance_ofLabel'])

# %%
person_nodes.head()
# Out:
#                                        person  \
# 0  https://geokb.wikibase.cloud/entity/Q44429
# 1  https://geokb.wikibase.cloud/entity/Q44747
# 2  https://geokb.wikibase.cloud/entity/Q45150
# 3  https://geokb.wikibase.cloud/entity/Q45150
# 4  https://geokb.wikibase.cloud/entity/Q45372
#
#                                    personLabel              personAltLabel  \
# 0                  Robert  Al-Chokhachy, Ph.D.  Robert Al-Chokhachy, Ph.D.
# 1                          Erik  Beever, Ph.D.          Erik Beever, Ph.D.
# 2  Muruleedhara (Murulee) N Byappanahalli, PhD                        None
# 3  Muruleedhara (Murulee) N Byappanahalli, PhD                        None
# 4                          Joseph Clark, Ph.D.                        None
#
#                 personDescription  \
# 0         Research Fish Biologist
# 1              Research Ecologist
# 2         Research Microbiologist
# 3         Research Microbiologist
# 4  Supervisory Research Ecologist
#
#                                       person_website
# 0  https://www.usgs.gov/staff-profiles/robert-al-...
# 1    https://www.usgs.gov/staff-profiles/erik-beever
# 2  https://www.usgs.gov/staff-profiles/muruleedha...
# 3  https://www.usgs.gov/staff-profiles/muruleedha...
# 4   https://www.usgs.gov/staff-profiles/joseph-clark

# %%
for _, row in person_nodes.iterrows():
    neo4j_session.run("""
        MERGE (n:Person {id: $id})
        ON CREATE SET n.label = $label,
                      n.altLabel = $altLabel,
                      n.description = $description,
                      n.website = $website
        """, 
        id=row['person'], 
        label=row['personLabel'], 
        altLabel=row['personAltLabel'], 
        description=row['personDescription'],
        website=row['person_website']
    )

# %%
article_nodes.head()
# Out:
#                                        article  \
# 0  https://geokb.wikibase.cloud/entity/Q144919
# 1  https://geokb.wikibase.cloud/entity/Q145083
# 2  https://geokb.wikibase.cloud/entity/Q145302
# 3  https://geokb.wikibase.cloud/entity/Q145370
# 4  https://geokb.wikibase.cloud/entity/Q145445
#
#                                         articleLabel  \
# 0  Proactive Rainbow Trout suppression reduces th...
# 1  Long-term population dynamics and conservation...
# 2  Vegetation responses to sagebrush-reduction tr...
# 3  Environmental DNA (eDNA): A tool for quantifyi...
# 4  Estimating population extinction thresholds wi...
#
#                                   articleDescription pub_year  \
# 0  a Article (Journal Article) published by Ameri...     2018
# 1  a Article (Journal Article) published by Canad...     2018
# 2  a Article (Journal Article) published by Elsev...     2018
# 3  a Article (Journal Article) published by PLOS ...     2018
# 4  a Article (Journal Article) published by Publi...     2018
#
#                              doi article_instance_ofLabel
# 0             10.1002/nafm.10177        scholarly article
# 1        10.1139/cjfas-2017-0466        scholarly article
# 2  10.1016/j.ecolind.2017.12.033        scholarly article
# 3   10.1371/journal.pone.0191720        scholarly article
# 4   10.1371/journal.pone.0191435        scholarly article

# %%
for _, row in article_nodes.iterrows():
    neo4j_session.run("""
        MERGE (n:Article {id: $id})
        ON CREATE SET n.label = $label,
                      n.description = $description,
                      n.published = $published,
                      n.doi = $doi,
                      n.instance_of = $instance_of
        """, 
        id=row['article'], 
        label=row['articleLabel'], 
        description=row['articleDescription'],
        published=row['pub_year'],
        doi=f"https://doi.org/{row['doi']}",
        instance_of=row['article_instance_ofLabel']
    )

# %%
org_relationships.head()
# Out:
#                                           org  \
# 0  https://geokb.wikibase.cloud/entity/Q44222
# 1  https://geokb.wikibase.cloud/entity/Q44228
# 2  https://geokb.wikibase.cloud/entity/Q44248
# 3  https://geokb.wikibase.cloud/entity/Q44256
# 4  https://geokb.wikibase.cloud/entity/Q44246
#
#                                 subsidiary_of
# 0  https://geokb.wikibase.cloud/entity/Q44363
# 1  https://geokb.wikibase.cloud/entity/Q44363
# 2  https://geokb.wikibase.cloud/entity/Q44363
# 3  https://geokb.wikibase.cloud/entity/Q44363
# 4  https://geokb.wikibase.cloud/entity/Q44363

# %%
for _, row in org_relationships.iterrows():
    neo4j_session.run("MATCH (a:Organization {id: $org}) "
                      "MATCH (b:Organization {id: $subsidiary_of}) "
                      "MERGE (a)-[:SUBSIDIARY_OF]->(b)",
                      org=row['org'], subsidiary_of=row['subsidiary_of'])

# %%
person_relationships.head()
# Out:
#                                        person  \
# 0  https://geokb.wikibase.cloud/entity/Q44429
# 1  https://geokb.wikibase.cloud/entity/Q44747
# 2  https://geokb.wikibase.cloud/entity/Q45150
# 3  https://geokb.wikibase.cloud/entity/Q45372
# 4  https://geokb.wikibase.cloud/entity/Q44845
#
#                               affiliated_with
# 0  https://geokb.wikibase.cloud/entity/Q44222
# 1  https://geokb.wikibase.cloud/entity/Q44222
# 2  https://geokb.wikibase.cloud/entity/Q44228
# 3  https://geokb.wikibase.cloud/entity/Q44222
# 4  https://geokb.wikibase.cloud/entity/Q44228

# %%
for _, row in person_relationships.iterrows():
    neo4j_session.run("MATCH (a:Person {id: $person}) "
                      "MATCH (b:Organization {id: $affiliated_with}) "
                      "MERGE (a)-[:AFFILIATED_WITH]->(b)",
                      person=row['person'], affiliated_with=row['affiliated_with'])

# %%
article_relationships.head()
# Out:
#                                        article  \
# 0  https://geokb.wikibase.cloud/entity/Q144919
# 1  https://geokb.wikibase.cloud/entity/Q145083
# 2  https://geokb.wikibase.cloud/entity/Q145302
# 3  https://geokb.wikibase.cloud/entity/Q145370
# 4  https://geokb.wikibase.cloud/entity/Q145445
#
#                                        person
# 0  https://geokb.wikibase.cloud/entity/Q44429
# 1  https://geokb.wikibase.cloud/entity/Q44429
# 2  https://geokb.wikibase.cloud/entity/Q44747
# 3  https://geokb.wikibase.cloud/entity/Q45150
# 4  https://geokb.wikibase.cloud/entity/Q45372

# %%
for _, row in article_relationships.iterrows():
    neo4j_session.run("MATCH (a:Article {id: $article}) "
                      "MATCH (b:Person {id: $person}) "
                      "MERGE (a)-[:HAS_AUTHOR]->(b)",
                      article=row['article'], person=row['person'])

# %% [markdown]
# # Demonstration Query
# The following query runs in the Neo4j instance and produces a listing of the cross-Center co-authorship in the Midcontinent Region.

# %%
result = neo4j_session.run("MATCH (ar:Article)-[:HAS_AUTHOR]->(a1:Person)-[:AFFILIATED_WITH]->(o1:Organization), "
    "(ar)-[:HAS_AUTHOR]->(a2:Person)-[:AFFILIATED_WITH]->(o2:Organization) "
    "WHERE a1 <> a2 AND o1 <> o2 "
    "RETURN a1.label, o1.label, ar.label, a2.label, o2.label"
)

midcontinent_coauthors = result.to_df()
midcontinent_coauthors
# Out:
#                             a1.label  \
# 0                    Craig A Jackson
# 1                    Jon Amberg, PhD
# 2                    Jon Amberg, PhD
# 3    Sara LeAnn (Caldwell)  Eldridge
# 4                   Elliott Barnhart
# ..                               ...
# 241                     James Larson
# 242            Keith A Loftin, Ph.D.
# 243        Zachary R Laughrey, Ph.D.
# 244                      Sean Bailey
# 245             Mary Anne Evans, PhD
#
#                                         o1.label  \
# 0    Upper Midwest Environmental Sciences Center
# 1    Upper Midwest Environmental Sciences Center
# 2    Upper Midwest Environmental Sciences Center
# 3           Wyoming-Montana Water Science Center
# 4           Wyoming-Montana Water Science Center
# ..                                           ...
# 241  Upper Midwest Environmental Sciences Center
# 242                  Kansas Water Science Center
# 243                  Kansas Water Science Center
# 244  Upper Midwest Environmental Sciences Center
# 245                   Great Lakes Science Center
#
#                                               ar.label               a2.label  \
# 0    A round-robin evaluation of the repeatability ...  Adam Sepulveda, Ph.D.
# 1    A round-robin evaluation of the repeatability ...  Adam Sepulveda, Ph.D.
# 2    Adding invasive species bio-surveillance to th...  Adam Sepulveda, Ph.D.
# 3    Integrating environmental DNA results with div...  Adam Sepulveda, Ph.D.
# 4    Integrating environmental DNA results with div...  Adam Sepulveda, Ph.D.
# ..                                                 ...                    ...
# 241  Associations between cyanobacteria and indices...              JC Nelson
# 242  Associations between cyanobacteria and indices...              JC Nelson
# 243  Associations between cyanobacteria and indices...              JC Nelson
# 244  Associations between cyanobacteria and indices...              JC Nelson
# 245  Associations between cyanobacteria and indices...              JC Nelson
#
#                                    o2.label
# 0    Northern Rocky Mountain Science Center
# 1    Northern Rocky Mountain Science Center
# 2    Northern Rocky Mountain Science Center
# 3    Northern Rocky Mountain Science Center
# 4    Northern Rocky Mountain Science Center
# ..                                      ...
# 241                     Midcontinent Region
# 242                     Midcontinent Region
# 243                     Midcontinent Region
# 244                     Midcontinent Region
# 245                     Midcontinent Region
#
# [246 rows x 5 columns]
