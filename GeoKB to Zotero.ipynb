# %% [markdown]
# This notebook was employed to pull some items together that represent publications in the GeoKB and get those built out to a Zotero group library for ongoing work. It's a bit ugly because I was working through some issues in how USGS Pubs Warehouse landing pages currently advertise their metadata. I had to go back into the library, update some items, and then build out new items.
#
# I'll likely revisit this in future to make this a more general process that works against the live USGS Pubs Warehouse API (at least until the schema.org situation is worked out for DOI resolution). It makes sense that we will have a logical two-way process between Zotero and the GeoKB. Zotero can be used to annotate and markup content, and annotation can be exploited to encode more connections into the GeoKB.

# %%
import os
import requests
from wbmaker import WikibaseConnection
from pyzotero import zotero
import pandas as pd

# %%
geokb = WikibaseConnection("GEOKB_CLOUD")

# %%
pw_core = pd.read_parquet('./data/pw_core.parquet')
pw_core = pw_core[['indexId','doi','publicationYear','title','pub_type','pub_subtype','series_title','numberOfPages']]

pw_creators = pd.read_parquet('./data/pw_creators.parquet')

def create_dict(row):
    return {
        'creatorType': row['creatorType'],
        'firstName': row['firstName'],
        'lastName': row['lastName'],
    }

pw_creators['creators'] = pw_creators.apply(create_dict, axis=1)
pw_creators.drop(columns=['creatorType','firstName','lastName'], inplace=True)
pw_creators = pw_creators.groupby('indexId', as_index=False).agg(list)

def chunk_list(long_list, chunk_size):
    for i in range(0, len(long_list), chunk_size):
        yield long_list[i:i + chunk_size]

# %%
mra_library = zotero.Zotero(
    "5137613",
    'group', 
    os.environ['ZOTERO_API_KEY']
)

# %%
user_agent = "GeoKB/0.1 (https://geokb.wikibase.cloud/; mailto:sbristol@usgs.gov) GeoKB-code/0.4"

def crossref_metadata(doi):
    url = f"https://api.crossref.org/works/{doi}"
    headers = {"User-Agent": user_agent}
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()["message"]
    else:
        return None

# %%
mra_zotero_items = mra_library.everything(mra_library.items())

# %%
df_mra_zotero_items = pd.DataFrame([i['data'] for i in mra_zotero_items if i['data']['itemType'] != 'attachment'])

df_mra_zotero_items['DOI'] = df_mra_zotero_items['extra'].apply(lambda x: x.replace('DOI: ', ''))
df_mra_zotero_items.drop(columns=[
    'extra',
    'dateAdded',
    'dateModified',
    'rights',
    'tags',
    'collections',
    'language',
    'accessDate',
    'archive',
    'archiveLocation',
    'relations',
    'callNumber',
    'seriesTitle',
    'place',
    'shortTitle',
    'abstractNote',
    'reportNumber',
    'reportType',
    'institution',
    'pages'
], inplace=True)

# %%
journal_article_template = mra_library.item_template('journalArticle')

# %%
item_updates = pd.merge(
    left=df_mra_zotero_items,
    right=pw_core.rename(columns={
        'doi': 'DOI', 
        'indexId': 'callNumber', 
        'series_title': 'seriesTitle', 
        'title': 'pw_title',
        'numberOfPages': 'pages'
    }),
    how="left",
    on="DOI"
)

item_updates = pd.merge(
    left=item_updates.drop(columns=['creators']),
    right=pw_creators.rename(columns={'indexId': 'callNumber'}),
    how="left",
    on="callNumber"
)

item_updates['itemType'] = 'journalArticle'
item_updates['libraryCatalog'] = "USGS Publications Warehouse (pubs.usgs.gov)"

item_updates['pages'] = item_updates['pages'].fillna('')
item_updates['creators'] = item_updates['creators'].fillna('')
item_updates['creators'] = item_updates['creators'].apply(lambda x: [] if len(x) == 0 else x)

item_updates.drop(columns=['publicationYear', 'pw_title', 'pub_type', 'pub_subtype'], inplace=True)

mra_library_updates = item_updates.to_dict(orient="records")

# %%
for update_list in chunk_list(mra_library_updates, 50):
    print(mra_library.update_items(update_list))
# Out:
# True
# True
# True

# %%
mra_items = geokb.url_sparql_query(
    sparql_url="https://geokb.wikibase.cloud/query/sparql?query=PREFIX%20wd%3A%20%3Chttps%3A%2F%2Fgeokb.wikibase.cloud%2Fentity%2F%3E%0APREFIX%20wdt%3A%20%3Chttps%3A%2F%2Fgeokb.wikibase.cloud%2Fprop%2Fdirect%2F%3E%0A%0ASELECT%20%3Fitem%20%3FitemLabel%20%3Fdoi%20%3FindexId%0AWHERE%20%7B%0A%20%20%3Fitem%20wdt%3AP1%20wd%3AQ152682%20.%0A%20%20OPTIONAL%20%7B%0A%20%20%20%20%3Fitem%20wdt%3AP74%20%3Fdoi%20.%0A%20%20%7D%0A%20%20OPTIONAL%20%7B%0A%20%20%20%20%3Fitem%20wdt%3AP114%20%3FindexId%20.%0A%20%20%7D%0A%20%20SERVICE%20wikibase%3Alabel%20%7B%20bd%3AserviceParam%20wikibase%3Alanguage%20%22en%22%20.%20%7D%0A%7D",
    output_format="dataframe"
)

# %%
journal_article_template
# Out:
# {'itemType': 'journalArticle',
#  'title': '',
#  'creators': [{'creatorType': 'author', 'firstName': '', 'lastName': ''}],
#  'abstractNote': '',
#  'publicationTitle': '',
#  'volume': '',
#  'issue': '',
#  'pages': '',
#  'date': '',
#  'series': '',
#  'seriesTitle': '',
#  'seriesText': '',
#  'journalAbbreviation': '',
#  'language': '',
#  'DOI': '',
#  'ISSN': '',
#  'shortTitle': '',
#  'url': '',
#  'accessDate': '',
#  'archive': '',
#  'archiveLocation': '',
#  'libraryCatalog': '',
#  'callNumber': '',
#  'rights': '',
#  'extra': '',
#  'tags': [],
#  'collections': [],
#  'relations': {}}

# %%
new_zotero_items = pw_core[pw_core['doi'].isin(mra_items[~mra_items['doi'].isin(df_mra_zotero_items['DOI'])]['doi'])].reset_index(drop=True)
new_zotero_items.rename(
    columns={
        'indexId': 'callNumber',
        'doi': 'DOI',
        'publicationYear': 'date',
        'series_title': 'seriesTitle',
        'numberOfPages': 'pages'
    },
    inplace=True
)
new_zotero_items.drop(columns=['pub_type','pub_subtype'], inplace=True)
new_zotero_items['itemType'] = 'journalArticle'
new_zotero_items['libraryCatalog'] = "USGS Publications Warehouse (pubs.usgs.gov)"

new_zotero_items = pd.merge(
    left=new_zotero_items,
    right=pw_creators.rename(columns={'indexId': 'callNumber'}),
    how="left",
    on="callNumber"
)

new_zotero_items['pages'] = new_zotero_items['pages'].fillna('')
new_zotero_items['creators'] = new_zotero_items['creators'].fillna('')
new_zotero_items['creators'] = new_zotero_items['creators'].apply(lambda x: [] if len(x) == 0 else x)

new_zotero_items['url'] = new_zotero_items['callNumber'].apply(lambda x: f"https://pubs.er.usgs.gov/publication/{x}")

# %%
for batch in chunk_list(new_zotero_items.to_dict(orient="records"), 50):
    print(mra_library.create_items(batch))
# Out:
# {'successful': {'0': {'key': '8RPK5HQV', 'version': 190, 'library': {'type': 'group', 'id': 5137613, 'name': 'Mineral Resource Assessments', 'links': {'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/groups/5137613/items/8RPK5HQV', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments/items/8RPK5HQV', 'type': 'text/html'}}, 'meta': {'createdByUser': {'id': 1119084, 'username': 'skybristol', 'name': 'Sky Bristol', 'links': {'alternate': {'href': 'https://www.zotero.org/skybristol', 'type': 'text/html'}}}, 'creatorSummary': 'Van Gosen et al.', 'parsedDate': '1996', 'numChildren': 0}, 'data': {'key': '8RPK5HQV', 'version': 190, 'itemType': 'journalArticle', 'title': 'Mineral resource assessment of the Custer National Forest in the Pryor Mountains, Carbon County, south-central Montana', 'creators': [{'creatorType': 'author', 'firstName': 'B. S.', 'lastName': 'Van Gosen'}, {'creatorType': 'author', 'firstName': 'A. B.', 'lastName': 'Wilson'}, {'creatorType': 'author', 'firstName': 'J. M.', 'lastName': 'Hammarstrom'}, {'creatorType': 'author', 'firstName': 'D. M.', 'lastName': 'Kulik'}], 'abstractNote': '', 'publicationTitle': '', 'volume': '', 'issue': '', 'pages': '', 'date': '1996', 'series': '', 'seriesTitle': 'Open-File Report', 'seriesText': '', 'journalAbbreviation': '', 'language': '', 'DOI': '10.3133/ofr96256', 'ISSN': '', 'shortTitle': '', 'url': 'https://pubs.er.usgs.gov/publication/ofr96256', 'accessDate': '', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'USGS Publications Warehouse (pubs.usgs.gov)', 'callNumber': 'ofr96256', 'rights': '', 'extra': '', 'tags': [], 'collections': [], 'relations': {}, 'dateAdded': '2023-08-02T17:41:32Z', 'dateModified': '2023-08-02T17:41:32Z'}}, '1': {'key': 'E9WMCEWK', 'version': 190, 'library': {'type': 'group', 'id': 5137613, 'name': 'Mineral Resource Assessments', 'links': {'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/groups/5137613/items/E9WMCEWK', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments/items/E9WMCEWK', 'type': 'text/html'}}, 'meta': {'createdByUser': {'id': 1119084, 'username': 'skybristol', 'name': 'Sky Bristol', 'links': {'alternate': {'href': 'https://www.zotero.org/skybristol', 'type': 'text/html'}}}, 'creatorSummary': 'Miller et al.', 'parsedDate': '1996', 'numChildren': 0}, 'data': {'key': 'E9WMCEWK', 'version': 190, 'itemType': 'journalArticle', 'title': 'Geology and mineral resources of the Stuyahok area, part of Holy Cross A-4 and A-5 quadrangles, Alaska', 'creators': [{'creatorType': 'author', 'firstName': 'Marti L.', 'lastName': 'Miller'}, {'creatorType': 'author', 'firstName': 'T. K.', 'lastName': 'Bundtzen'}, {'creatorType': 'author', 'firstName': 'W. J.', 'lastName': 'Keith'}, {'creatorType': 'author', 'firstName': 'E. A.', 'lastName': 'Bailey'}, {'creatorType': 'author', 'firstName': 'D. P.', 'lastName': 'Bickerstaff'}], 'abstractNote': '', 'publicationTitle': '', 'volume': '', 'issue': '', 'pages': '', 'date': '1996', 'series': '', 'seriesTitle': 'Open-File Report', 'seriesText': '', 'journalAbbreviation': '', 'language': '', 'DOI': '10.3133/ofr96505A', 'ISSN': '', 'shortTitle': '', 'url': 'https://pubs.er.usgs.gov/publication/ofr96505A', 'accessDate': '', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'USGS Publications Warehouse (pubs.usgs.gov)', 'callNumber': 'ofr96505A', 'rights': '', 'extra': '', 'tags': [], 'collections': [], 'relations': {}, 'dateAdded': '2023-08-02T17:41:32Z', 'dateModified': '2023-08-02T17:41:32Z'}}, '2': {'key': 'SWJX8BAH', 'version': 190, 'library': {'type': 'group', 'id': 5137613, 'name': 'Mineral Resource Assessments', 'links': {'alternate': {'href': 'https://www.zotero.or ...
# {'successful': {'0': {'key': 'IZIIT8W9', 'version': 191, 'library': {'type': 'group', 'id': 5137613, 'name': 'Mineral Resource Assessments', 'links': {'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/groups/5137613/items/IZIIT8W9', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments/items/IZIIT8W9', 'type': 'text/html'}}, 'meta': {'createdByUser': {'id': 1119084, 'username': 'skybristol', 'name': 'Sky Bristol', 'links': {'alternate': {'href': 'https://www.zotero.org/skybristol', 'type': 'text/html'}}}, 'creatorSummary': 'Werner et al.', 'parsedDate': '1998', 'numChildren': 0}, 'data': {'key': 'IZIIT8W9', 'version': 191, 'itemType': 'journalArticle', 'title': 'International strategic mineral issues summary report– Tungsten', 'creators': [{'creatorType': 'author', 'firstName': 'Antony B. T.', 'lastName': 'Werner'}, {'creatorType': 'author', 'firstName': 'W. David', 'lastName': 'Sinclair'}, {'creatorType': 'author', 'firstName': 'Earle B.', 'lastName': 'Amey'}], 'abstractNote': '', 'publicationTitle': '', 'volume': '', 'issue': '', 'pages': '86', 'date': '1998', 'series': '', 'seriesTitle': 'Circular', 'seriesText': '', 'journalAbbreviation': '', 'language': '', 'DOI': '10.3133/cir930O', 'ISSN': '', 'shortTitle': '', 'url': 'https://pubs.er.usgs.gov/publication/cir930O', 'accessDate': '', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'USGS Publications Warehouse (pubs.usgs.gov)', 'callNumber': 'cir930O', 'rights': '', 'extra': '', 'tags': [], 'collections': [], 'relations': {}, 'dateAdded': '2023-08-02T17:41:39Z', 'dateModified': '2023-08-02T17:41:39Z'}}, '1': {'key': 'PCU99EHE', 'version': 191, 'library': {'type': 'group', 'id': 5137613, 'name': 'Mineral Resource Assessments', 'links': {'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/groups/5137613/items/PCU99EHE', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments/items/PCU99EHE', 'type': 'text/html'}}, 'meta': {'createdByUser': {'id': 1119084, 'username': 'skybristol', 'name': 'Sky Bristol', 'links': {'alternate': {'href': 'https://www.zotero.org/skybristol', 'type': 'text/html'}}}, 'creatorSummary': 'Winkler et al.', 'parsedDate': '1992', 'numChildren': 0}, 'data': {'key': 'PCU99EHE', 'version': 191, 'itemType': 'journalArticle', 'title': 'The Alaska Mineral Resource Assessment Program: Background information to accompany geologic and mineral-resource maps of the Cordova and Middleton Island quadrangles, southern Alaska', 'creators': [{'creatorType': 'author', 'firstName': 'Gary R.', 'lastName': 'Winkler'}, {'creatorType': 'author', 'firstName': 'George', 'lastName': 'Plafker'}, {'creatorType': 'author', 'firstName': 'R. J.', 'lastName': 'Goldfarb'}, {'creatorType': 'author', 'firstName': 'J. E.', 'lastName': 'Case'}], 'abstractNote': '', 'publicationTitle': '', 'volume': '', 'issue': '', 'pages': '', 'date': '1992', 'series': '', 'seriesTitle': 'Circular', 'seriesText': '', 'journalAbbreviation': '', 'language': '', 'DOI': '10.3133/cir1076', 'ISSN': '', 'shortTitle': '', 'url': 'https://pubs.er.usgs.gov/publication/cir1076', 'accessDate': '', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'USGS Publications Warehouse (pubs.usgs.gov)', 'callNumber': 'cir1076', 'rights': '', 'extra': '', 'tags': [], 'collections': [], 'relations': {}, 'dateAdded': '2023-08-02T17:41:39Z', 'dateModified': '2023-08-02T17:41:39Z'}}, '2': {'key': 'D5PGX932', 'version': 191, 'library': {'type': 'group', 'id': 5137613, 'name': 'Mineral Resource Assessments', 'links': {'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/groups/5137613/items/D5P ...
# {'successful': {'0': {'key': 'NRCNRTDT', 'version': 192, 'library': {'type': 'group', 'id': 5137613, 'name': 'Mineral Resource Assessments', 'links': {'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/groups/5137613/items/NRCNRTDT', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments/items/NRCNRTDT', 'type': 'text/html'}}, 'meta': {'createdByUser': {'id': 1119084, 'username': 'skybristol', 'name': 'Sky Bristol', 'links': {'alternate': {'href': 'https://www.zotero.org/skybristol', 'type': 'text/html'}}}, 'creatorSummary': 'Tooker and Wedow', 'parsedDate': '1980', 'numChildren': 0}, 'data': {'key': 'NRCNRTDT', 'version': 192, 'itemType': 'journalArticle', 'title': 'Preliminary map of zinc provinces in the conterminous United States', 'creators': [{'creatorType': 'author', 'firstName': 'Edwin Wilson', 'lastName': 'Tooker'}, {'creatorType': 'author', 'firstName': 'Helmuth', 'lastName': 'Wedow'}], 'abstractNote': '', 'publicationTitle': '', 'volume': '', 'issue': '', 'pages': '', 'date': '1980', 'series': '', 'seriesTitle': 'Open-File Report', 'seriesText': '', 'journalAbbreviation': '', 'language': '', 'DOI': '10.3133/ofr79576Q', 'ISSN': '', 'shortTitle': '', 'url': 'https://pubs.er.usgs.gov/publication/ofr79576Q', 'accessDate': '', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'USGS Publications Warehouse (pubs.usgs.gov)', 'callNumber': 'ofr79576Q', 'rights': '', 'extra': '', 'tags': [], 'collections': [], 'relations': {}, 'dateAdded': '2023-08-02T17:41:46Z', 'dateModified': '2023-08-02T17:41:46Z'}}, '1': {'key': '58HSZXR9', 'version': 192, 'library': {'type': 'group', 'id': 5137613, 'name': 'Mineral Resource Assessments', 'links': {'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/groups/5137613/items/58HSZXR9', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments/items/58HSZXR9', 'type': 'text/html'}}, 'meta': {'createdByUser': {'id': 1119084, 'username': 'skybristol', 'name': 'Sky Bristol', 'links': {'alternate': {'href': 'https://www.zotero.org/skybristol', 'type': 'text/html'}}}, 'creatorSummary': 'Berg', 'parsedDate': '1980', 'numChildren': 0}, 'data': {'key': '58HSZXR9', 'version': 192, 'itemType': 'journalArticle', 'title': 'The Alaska Mineral Resource Assessment Program: Guide to information about the geology and mineral resources of the Ketchikan and Prince Rupert quadrangles, southeastern Alaska', 'creators': [{'creatorType': 'author', 'firstName': 'Henry C.', 'lastName': 'Berg'}], 'abstractNote': '', 'publicationTitle': '', 'volume': '', 'issue': '', 'pages': '', 'date': '1980', 'series': '', 'seriesTitle': 'Open-File Report', 'seriesText': '', 'journalAbbreviation': '', 'language': '', 'DOI': '10.3133/ofr80794', 'ISSN': '', 'shortTitle': '', 'url': 'https://pubs.er.usgs.gov/publication/ofr80794', 'accessDate': '', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'USGS Publications Warehouse (pubs.usgs.gov)', 'callNumber': 'ofr80794', 'rights': '', 'extra': '', 'tags': [], 'collections': [], 'relations': {}, 'dateAdded': '2023-08-02T17:41:47Z', 'dateModified': '2023-08-02T17:41:47Z'}}, '2': {'key': 'JHU7SNP9', 'version': 192, 'library': {'type': 'group', 'id': 5137613, 'name': 'Mineral Resource Assessments', 'links': {'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/groups/5137613/items/JHU7SNP9', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments/items/JHU7SNP9', 'type': 'text/html'}}, 'meta': {'createdByUser': {'id': 1119084, 'username': 'skybristol', 'name': 'Sky Bristol', 'links': {'alternate': {'href' ...
# {'successful': {'0': {'key': 'STUGFRRV', 'version': 193, 'library': {'type': 'group', 'id': 5137613, 'name': 'Mineral Resource Assessments', 'links': {'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/groups/5137613/items/STUGFRRV', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments/items/STUGFRRV', 'type': 'text/html'}}, 'meta': {'createdByUser': {'id': 1119084, 'username': 'skybristol', 'name': 'Sky Bristol', 'links': {'alternate': {'href': 'https://www.zotero.org/skybristol', 'type': 'text/html'}}}, 'creatorSummary': 'Bergquist et al.', 'parsedDate': '1988', 'numChildren': 0}, 'data': {'key': 'STUGFRRV', 'version': 193, 'itemType': 'journalArticle', 'title': 'Mineral resources of the Sheldon Contiguous Wilderness Study Area, Washoe County, Nevada', 'creators': [{'creatorType': 'author', 'firstName': 'J.R.', 'lastName': 'Bergquist'}, {'creatorType': 'author', 'firstName': 'Donald', 'lastName': 'Plouff'}, {'creatorType': 'author', 'firstName': 'L.R.', 'lastName': 'Esparza'}], 'abstractNote': '', 'publicationTitle': '', 'volume': '', 'issue': '', 'pages': '', 'date': '1988', 'series': '', 'seriesTitle': 'Open-File Report', 'seriesText': '', 'journalAbbreviation': '', 'language': '', 'DOI': '10.3133/ofr88246', 'ISSN': '', 'shortTitle': '', 'url': 'https://pubs.er.usgs.gov/publication/ofr88246', 'accessDate': '', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'USGS Publications Warehouse (pubs.usgs.gov)', 'callNumber': 'ofr88246', 'rights': '', 'extra': '', 'tags': [], 'collections': [], 'relations': {}, 'dateAdded': '2023-08-02T17:41:52Z', 'dateModified': '2023-08-02T17:41:52Z'}}, '1': {'key': 'IPB28J3X', 'version': 193, 'library': {'type': 'group', 'id': 5137613, 'name': 'Mineral Resource Assessments', 'links': {'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/groups/5137613/items/IPB28J3X', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments/items/IPB28J3X', 'type': 'text/html'}}, 'meta': {'createdByUser': {'id': 1119084, 'username': 'skybristol', 'name': 'Sky Bristol', 'links': {'alternate': {'href': 'https://www.zotero.org/skybristol', 'type': 'text/html'}}}, 'creatorSummary': 'Bliss et al.', 'parsedDate': '1988', 'numChildren': 0}, 'data': {'key': 'IPB28J3X', 'version': 193, 'itemType': 'journalArticle', 'title': 'Mineral resource assessment of the Wiseman 1° by 3° quadrangle, Alaska', 'creators': [{'creatorType': 'author', 'firstName': 'James D.', 'lastName': 'Bliss'}, {'creatorType': 'author', 'firstName': 'W.P.', 'lastName': 'Brosge'}, {'creatorType': 'author', 'firstName': 'J. T.', 'lastName': 'Dillon'}, {'creatorType': 'author', 'firstName': 'J.T.', 'lastName': 'Dutro'}, {'creatorType': 'author', 'firstName': 'J.B.', 'lastName': 'Cathrall'}, {'creatorType': 'author', 'firstName': 'J. W.', 'lastName': 'Cady'}], 'abstractNote': '', 'publicationTitle': '', 'volume': '', 'issue': '', 'pages': '', 'date': '1988', 'series': '', 'seriesTitle': 'Open-File Report', 'seriesText': '', 'journalAbbreviation': '', 'language': '', 'DOI': '10.3133/ofr88533', 'ISSN': '', 'shortTitle': '', 'url': 'https://pubs.er.usgs.gov/publication/ofr88533', 'accessDate': '', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'USGS Publications Warehouse (pubs.usgs.gov)', 'callNumber': 'ofr88533', 'rights': '', 'extra': '', 'tags': [], 'collections': [], 'relations': {}, 'dateAdded': '2023-08-02T17:41:52Z', 'dateModified': '2023-08-02T17:41:52Z'}}, '2': {'key': 'R5FC627P', 'version': 193, 'library': {'type': 'group', 'id': 5137613, 'name': 'Mineral Resource Assessments', 'links': {'alternate': {'href': 'https://www.zotero.org/groups/mineral_resource_assessments', 'type': 'text/html'}}}, 'links': {'self': ...
